# %%
import pandas as pd
full_articles = pd.read_csv("../data/external/products.csv", dtype='string')
articles_clean = pd.read_parquet("../data/processed/articles_clean.parquet").query("forSale.notna()")

# %%
# Add columns from full_articles to for_sale_articles (now called articles)
# Drop specified columns from articles_clean before merging
cols_to_drop = ['priceEUR', 'priceNOK', 'priceDKK', 'forSale', 'sizeId', 'brandId', 'categoryId']
articles = articles_clean.drop(columns=cols_to_drop, errors='ignore').copy()
cols_to_add = ['description', 'color']
articles = articles.merge(
    full_articles[['sku'] + cols_to_add],
    on='sku',
    how='left'
)

# %%
# number of unique groupid
print(articles['groupId'].nunique())
# Out:
# 1738

# %%
articles.sample()
# Out:
#                sku groupId                       name      brand  \
# 31516  261525-F115  261396  Bh utan bygel Lovely Lace  Miss Mary
#
#                            category priceSEK  \
# 31516  Bh utan bygel,Bh,Underkläder      549
#
#                                              description color
# 31516  Lovely Lace. En bh utan bygel från Miss Mary, ...  Grön

# %%
#count proportion of missing values in each column
articles.isnull().mean()
# Out:
# sku            0.000000
# groupId        0.000000
# name           0.004318
# brand          0.000000
# category       0.000000
# priceSEK       0.000000
# description    0.006039
# color          0.027778
# dtype: float64

# %% [markdown]
# Removing bugs

# %%
na_name = articles[articles["name"].isna()]
na_name
# Out:
#                  sku groupId  name            brand category priceSEK  \
# 2682       280119-40  280117  <NA>  Embla of Sweden  unknown     1249
# 2683       280119-39  280117  <NA>  Embla of Sweden  unknown     1249
# 2684       280119-38  280117  <NA>  Embla of Sweden  unknown     1249
# 2685       280119-37  280117  <NA>  Embla of Sweden  unknown     1249
# 2686       280119-36  280117  <NA>  Embla of Sweden  unknown     1249
# ...              ...     ...   ...              ...      ...      ...
# 33115         973036  973036  <NA>          unknown  unknown       72
# 33116     262130-80D  262130  <NA>         Swegmark  unknown      881
# 33117       262152-L  262150  <NA>         Swegmark  unknown      337
# 33118      262137-XL  262135  <NA>         Swegmark  unknown      190
# 33119  262144-110BCD  262142  <NA>        Glamorise  unknown      499
#
#       description color
# 2682         <NA>  <NA>
# 2683         <NA>  <NA>
# 2684         <NA>  <NA>
# 2685         <NA>  <NA>
# 2686         <NA>  <NA>
# ...           ...   ...
# 33115        <NA>  <NA>
# 33116        <NA>  <NA>
# 33117        <NA>  <NA>
# 33118        <NA>  <NA>
# 33119        <NA>  <NA>
#
# [143 rows x 8 columns]

# %%
# Drop rows with missing name and drop the corresponding rows from articles
articles = articles[articles["name"].notna()].reset_index(drop=True)

# %%
# Print all unique color values, one per line, to avoid truncation
for c in articles['color'].unique():
    print(repr(c))
# Out:
# <NA>
# 'Svart'
# 'Off-white'
# 'Svart,Svart'
# 'Grå,Grå'
# 'Vit,Vit'
# 'Rosa,Rosa'
# 'Grön,Grön'
# 'Blå,Blå'
# 'Vinröd,Vinröd'
# 'Röd,Röd'
# 'Cognac,Cognac'
# 'Linne,Linne'
# 'Brun,Brun'
# 'Gråblå,Gråblå'
# 'Champagne'
# 'Beige'
# 'Off-white,Off-white'
# 'Indigo,Indigo'
# 'Sand,Sand'
# 'Grön,Grön,Grön'
# 'Multi,Multi'
# 'Vit,Vit,Vit'
# 'Multi,Multi,Multi'
# 'Mörkgrön,Mörkgrön'
# 'Rost,Rost'
# 'Gul,Gul'
# 'Röd,Röd,Röd'
# 'Vit'
# 'Antracit'
# 'Creme,Creme'
# 'Beige,Beige'
# 'Ljusblå,Ljusblå'
# 'Ljung,Ljung'
# 'Turkos,Turkos'
# 'Vit,Vit,Vit,Vit'
# 'Linne,Linne,Linne,Linne'
# 'Mörkblå,Mörkblå'
# 'Grå,Grå,Grå'
# 'Svart,Svart,Svart'
# 'Marin,Marin'
# 'Mellanblå,Mellanblå'
# 'Ljusgrå'
# 'Lila,Lila'
# 'Rosa'
# 'Linne'
# 'Brun'
# 'Marin'
# 'Grön'
# 'Beige,Beige,Beige'
# 'Brun,Brun,Brun'
# 'Blå'
# 'Röd'
# 'Lila'
# 'Ljung'
# 'Ljusgrå,Ljusgrå'
# 'Vit/beige,Vit/beige'
# 'Mörkgrå,Mörkgrå'
# 'Aqua,Aqua'
# 'Ljusbrun,Ljusbrun'
# 'Gammalrosa,Gammalrosa'
# 'Rost,Rost,Rost,Rost,Rost,Rost'
# 'Kaki,Kaki'
# 'Off-white,Off-white,Off-white,Off-white,Off-white,Off-white'
# 'Indigo,Indigo,Indigo,Indigo,Indigo,Indigo'
# 'Rosa,Rosa,Rosa,Rosa,Rosa,Rosa'
# 'Mörkgrå,Mörkgrå,Mörkgrå,Mörkgrå,Mörkgrå,Mörkgrå'
# 'Off-white,Off-white,Off-white,Off-white'
# 'Mörkgrå'
# 'Mörkgrön'
# 'Greige,Greige'
# 'Svart/grå'
# 'Blå/vit'
# 'Vinröd'
# 'Vit/beige'
# 'Blå,Blå,Blå'
# 'Oblekt,Oblekt,Oblekt'
# 'Svart/grå,Svart/grå,Svart/grå'
# 'Grå'
# 'Mintgrön,Mintgrön,Mintgrön'
# 'Gul,Gul,Gul'
# 'Rosa,Rosa,Rosa'
# 'Turkos,Turkos,Turkos'
# 'Vanilj'
# 'Beige/brun'
# 'Mörkblå'
# 'Puderrosa'
# 'Nougat'
# 'Taupe'
# 'Korall'
# 'Off-white,Off-white,Off-white'
# 'Svart/grå,Svart/grå'
# 'Blå/mönstrad'
# 'Gråmelerad'
# 'Multi'
# 'Duvblå'
# 'Svart/vit'
# 'Vanilj,Vanilj,Vanilj'
# 'Svart/mönstrad'
# 'Röd,Röd,Röd,Röd'
# 'Röd,Röd,Röd,Röd,Röd,Röd'
# 'Hallon'
# 'Grå/rosa,Grå/rosa'
# 'Grå/svart'
# 'Vanilj,Vanilj'
# 'Mörkgrå,Mörkgrå,Mörkgrå'
# 'Klarblå,Klarblå,Klarblå'
# 'Ljus blå,Ljus blå,Ljus blå'
# 'Blush,Blush,Blush'
# 'Oliv,Oliv,Oliv'
# 'Blå/grön,Blå/grön,Blå/grön'
# 'Mellanrosa,Mellanrosa,Mellanrosa'
# 'Kamel,Kamel,Kamel'
# 'Mellangrå,Mellangrå,Mellangrå'
# 'Lila,Lila,Lila'
# 'Natur,Natur,Natur'
# 'Ljusturkos,Ljusturkos,Ljusturkos'
# 'Cerise,Cerise,Cerise'
# 'Gråmelerad,Gråmelerad,Gråmelerad'
# 'Ljusgrå mix,Ljusgrå mix,Ljusgrå mix'
# 'Jeansblå,Jeansblå,Jeansblå'
# 'Grålila,Grålila,Grålila'
# 'Lavendel,Lavendel,Lavendel'
# 'Orange mix,Orange mix,Orange mix'
# 'Puderrosa,Puderrosa,Puderrosa'
# 'Mellanbrun,Mellanbrun,Mellanbrun'
# 'Ljus beige,Ljus beige,Ljus beige'
# 'Havsblå,Havsblå,Havsblå'
# 'Marinblå,Marinblå,Marinblå'
# 'Turkos'
# 'Grå,Svart'
# 'Natur'
# 'Transparent'
# 'Gammalrosa'
# 'Svart/röd'
# 'Blå/vit,Blå/vit'
# 'Grön/Svart'
# 'Svart,Svart,Svart,Svart'
# 'Ljusgrön,Ljusgrön'
# 'Ljusgrön,Ljusgrön,Ljusgrön'
# 'Svart/vit,Svart/vit'
# 'Vinröd/svart'
# 'Gråmelerad,Gråmelerad'
# 'Sand'
# 'Ljusrosa'
# 'Nougat,Nougat'
# 'Ljusrosa,Ljusrosa'
# 'Ljusgul'
# 'Rosa/vit'
# 'Aqua'
# 'Aubergine'
# 'Lila/rosa'
# 'Ljusblå'
# 'Petrol'
# 'Svart/marinmönstrad'
# 'Kaki'
# 'Blågrå'
# 'Korall,Korall'
# 'Creme'
# 'Orange'
# 'Gul'
# 'Plommonlila,Plommonlila'
# 'Champagne,Champagne,Champagne'
# 'Brun,Brun,Brun,Brun,Brun,Brun,Brun,Brun'
# 'Vit,Vit,Vit,Vit,Vit,Vit,Vit,Vit'
# 'Vit/beige,Vit/beige,Vit/beige'
# 'Marin,Marin,Marin'
# 'Korall,Korall,Korall'
# 'Ljusrosa,Ljusrosa,Ljusrosa,Ljusrosa,Ljusrosa,Ljusrosa'
# 'Ljung,Ljung,Ljung'
# 'Grå/vit,Grå/vit'
# 'Olivgrön'
# 'Denim'
# 'Mullvad'
# 'Mörkröd,Mörkröd'
# 'Linne,Linne,Linne,Linne,Linne,Linne,Linne,Linne'
# 'Kaki,Kaki,Kaki,Kaki'
# 'Aqua,Aqua,Aqua,Aqua,Aqua,Aqua'
# 'Ljung,Ljung,Ljung,Ljung,Ljung,Ljung,Ljung,Ljung'
# 'Grön,Grön,Grön,Grön,Grön,Grön,Grön,Grön'
# 'Ljusrosa,Ljusrosa,Ljusrosa,Ljusrosa,Ljusrosa,Ljusrosa,Ljusrosa,Ljusrosa'
# 'Grön,Grön,Grön,Grön,Grön,Grön'
# 'Marin,Marin,Marin,Marin,Marin,Marin'
# 'Syrénlila,Syrénlila'
# 'Syrénlila,Syrénlila,Syrénlila,Syrénlila'
# 'Svart/silver'
# 'Guld,Guld,Guld'
# 'Champagne,Champagne'
# 'Svart/blå'
# 'Pralin,Pralin'
# 'Antracit,Antracit'
# 'Mörkgrön,Mörkgrön,Mörkgrön,Mörkgrön,Mörkgrön,Mörkgrön'
# 'Brun,Brun,Brun,Brun,Brun,Brun'
# 'Mörkrosa,Mörkrosa,Mörkrosa,Mörkrosa,Mörkrosa,Mörkrosa,Mörkrosa,Mörkrosa'
# 'Mörkgrå,Mörkgrå,Mörkgrå,Mörkgrå,Mörkgrå,Mörkgrå,Mörkgrå,Mörkgrå'
# 'Beige,Beige,Beige,Beige,Beige,Beige,Beige,Beige'
# 'Blå,Blå,Blå,Blå,Blå,Blå,Blå,Blå'
# 'Grå,Grå,Grå,Grå,Grå,Grå,Grå,Grå'
# 'Mörkgrön,Mörkgrön,Mörkgrön,Mörkgrön,Mörkgrön,Mörkgrön,Mörkgrön,Mörkgrön'
# 'Marin,Marin,Marin,Marin,Marin,Marin,Marin,Marin'
# 'Vit,Vit,Vit,Vit,Vit,Vit'
# 'Grå,Grå,Grå,Grå,Grå,Grå'
# 'Blå,Blå,Blå,Blå,Blå,Blå'
# 'Beige,Beige,Beige,Beige,Beige,Beige'
# 'Mörkrosa,Mörkrosa,Mörkrosa,Mörkrosa,Mörkrosa,Mörkrosa'
# 'Ljung,Ljung,Ljung,Ljung,Ljung,Ljung'
# 'Aqua,Aqua,Aqua,Aqua,Aqua,Aqua,Aqua,Aqua'
# 'Rosa,Rosa,Rosa,Rosa,Rosa,Rosa,Rosa,Rosa'
# 'Linne,Linne,Linne,Linne,Linne,Linne'

# %%
# Deduplicate repeated color names in the 'color' column
def dedup_color(val):
    if pd.isna(val):
        return val
    seen = set()
    tokens = [x.strip() for x in str(val).split(',')]
    deduped = []
    for token in tokens:
        if token and token not in seen:
            deduped.append(token)
            seen.add(token)
    return ','.join(deduped) if deduped else pd.NA

articles['color'] = articles['color'].apply(dedup_color)

# %% [markdown]
# ## SKU

# %%
articles.drop_duplicates(subset=['sku'], keep=False)
# Out:
#                sku  groupId                    name              brand  \
# 0           970100   970100     Frakt- & exp.avgift            unknown
# 1           790196   790196        Fingerborg 17 mm  Ateljé Margaretha
# 2      565301-7070   565301          Bygel-bh Fleur          Rosa Faia
# 3      565301-8095   565301          Bygel-bh Fleur          Rosa Faia
# 4      565301-8090   565301          Bygel-bh Fleur          Rosa Faia
# ...            ...      ...                     ...                ...
# 32972  270548-L_XL   270547   Big-T Emilia av bambu             Åshild
# 32973  260965-H115   260965       Body Happy Hearts          Miss Mary
# 32974      12025FI  12025FI  Åshild A-kat höst25 FI            unknown
# 32975      12025NO  12025NO  Åshild A-kat höst25 NO            unknown
# 32976      12025DK  12025DK    Åshild A-kat höst DK            unknown
#
#                              category priceSEK  \
# 0                             unknown       69
# 1       Sytillbehör,Vardagshjälpmedel       19
# 2             Bygel-bh,Bh,Underkläder      749
# 3             Bygel-bh,Bh,Underkläder      749
# 4             Bygel-bh,Bh,Underkläder      749
# ...                               ...      ...
# 32972                   Sovkläder,Dam      298
# 32973  Bh utan bygel,Body,Underkläder      849
# 32974                         unknown        0
# 32975                         unknown        0
# 32976                         unknown        0
#
#                                              description  color
# 0                                                   <NA>   <NA>
# 1                             Fingerborg, storlek 17 mm.   <NA>
# 2      Elegant bygel- bh från Rosa Faias Fleur serie ...  Svart
# 3      Elegant bygel- bh från Rosa Faias Fleur serie ...  Svart
# 4      Elegant bygel- bh från Rosa Faias Fleur serie ...  Svart
# ...                                                  ...    ...
# 32972  Big-T, tillverkat i mjuk bambu är den perfekta...  Svart
# 32973  Formande body från Miss Mary med förstärkt fra...    Vit
# 32974                                               <NA>   <NA>
# 32975                                               <NA>   <NA>
# 32976                                               <NA>   <NA>
#
# [32977 rows x 8 columns]

# %%
# Save the cleaned articles DataFrame to Parquet without changing dtypes
articles.to_parquet("../data/processed/articles_clean.parquet", index=False)

articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32977 entries, 0 to 32976
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          32977 non-null  string
#  1   groupId      32977 non-null  string
#  2   name         32977 non-null  string
#  3   brand        32977 non-null  string
#  4   category     32977 non-null  string
#  5   priceSEK     32977 non-null  string
#  6   description  32920 non-null  string
#  7   color        32159 non-null  object
# dtypes: object(1), string(7)
# memory usage: 2.0+ MB

# %%
print(len(articles['sku'].unique()))
print(len(articles['groupId'].unique()))
# Out:
# 32977
# 1730

# %%
# Deduplicate so that for each groupId, keep the first row for all columns except 'color', 
# which should be a list of all colors from merged rows (excluding missing/unknown/nan/none).
def merge_colors(series):
    # Remove missing/unknown/nan/none and deduplicate
    colors = [str(c).strip() for c in series if pd.notna(c) and str(c).strip().lower() not in {"", "unknown", "nan", "none"}]
    return list(sorted(set(colors))) if colors else []

articles = articles.sort_values("sku")  # Ensure deterministic "first" row
articles = articles.groupby("groupId", as_index=False).agg(
    {col: (merge_colors if col == "color" else "first") for col in articles.columns if col != "sku"}
)

# %%
articles.to_parquet("../data/processed/articles_for_recs.parquet", index=False)
