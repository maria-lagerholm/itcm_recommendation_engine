# %%
import pandas as pd

def load_filtered_transactions(
    trans_path="/workspace/data/processed/transactions_clean.parquet",
    avail_path="/workspace/data/processed/articles_for_recs.parquet",
    bad_ids={"12025DK", "12025FI", "12025NO", "12025SE", "970300", "459978"},
    cols=("shopUserId", "orderId", "groupId", "category", "brand"),
):
    global df 
    df = pd.read_parquet(trans_path, columns=list(cols))
    avail_df = pd.read_parquet(avail_path)

    gid = df["groupId"].astype(str).str.strip()
    avail_ids = set(avail_df["groupId"].astype(str).str.strip().unique())

    df = df.loc[gid.isin(avail_ids) & ~gid.isin(bad_ids)].reset_index(drop=True)
    return df

df = load_filtered_transactions()

# %%
import pandas as pd

def aggregate_by_groupid(
    df: pd.DataFrame,
    item_col: str = "groupId",
    brand_col: str = "brand",
    category_col: str = "category",
) -> pd.DataFrame:
    """
    Aggregate by groupId, count occurrences, and keep brand and category.
    Returns a DataFrame with [groupId, brand, category, transactions].
    """
    agg_df = (
        df.groupby([item_col, brand_col, category_col])
          .size()
          .reset_index(name="transactions")
    )
    return agg_df

pairs = aggregate_by_groupid(df)

# %%
pairs.sort_values(by="transactions", ascending=False)
# Out:
#      groupId                brand  \
# 466   261637        Locköstrumpan
# 288   260695               Louise
# 128   240187               Åshild
# 35    210338               Åshild
# 41    210695               Åshild
# ...      ...                  ...
# 794   270619  Abecita by swegmark
# 1083  340459             Daylight
# 1086  340572               Singer
# 197   260183                Trofé
# 1222  500397                Linea
#
#                                          category  transactions
# 466             Stödstrumpor,Strumpor,Underkläder          6223
# 288   Bh-toppar,Bh,Bh utan kupstorlek,Underkläder          5716
# 128                    Mjukisbyxor,Mysplagg,Byxor          4562
# 35                      Toppar,Överdelar,T-shirts          4063
# 41                               Toppar,Överdelar          3952
# ...                                           ...           ...
# 794                          Badkläder,Baddräkter             1
# 1083    Synhjälpmedel,Vardagshjälpmedel,Belysning             1
# 1086         Sytillbehör,Symaskiner och tillbehör             1
# 197                            Underkläder,Trosor             1
# 1222                          Täcken,Bädd (linea)             1
#
# [1476 rows x 4 columns]

# %%
# Find all fully unique category values present in the pairs DataFrame (no splitting)
unique_categories = sorted(pairs['category'].dropna().unique())
unique_categories
# Out:
# ['Accessoarer',
#  'Accessoarer,Bh,Underkläder,Bh-tillbehör',
#  'Accessoarer,Handskar & vantar',
#  'Accessoarer,Herr,Kepsar & mössor',
#  'Accessoarer,Kepsar & mössor',
#  'Accessoarer,Mössor & hattar',
#  'Accessoarer,Väskor',
#  'Bad,Duschdraperier',
#  'Bad,Frottéhanddukar & badlakan',
#  'Baddräkter,Badkläder',
#  'Baddräkter,Badkläder,Dam',
#  'Badkläder,Baddräkter',
#  'Badkläder,Baddräkter,Kjolbaddräkter',
#  'Badkläder,Bikini',
#  'Badkläder,Dam',
#  'Badkläder,Dam,Tankini',
#  'Badkläder,Sarong',
#  'Badkläder,Tankini',
#  'Badrum/WC',
#  'Badrum/WC,Ansiktsvård',
#  'Badrum/WC,Vardagshjälpmedel,Stödartiklar',
#  'Badrumsmattor,Bad',
#  'Badskor,Badkläder',
#  'Batteridrivna ljus',
#  'Belysning,Barnrummet,Natt & garderobslampor',
#  'Belysning,Batteridrivna ljus',
#  'Belysning,Vardagshjälpmedel,Batterier',
#  'Bh utan bygel,Baddräkter,Badkläder',
#  'Bh utan bygel,Bh,Sport-bh,Bygel-bh,Underkläder',
#  'Bh utan bygel,Bh,Underkläder',
#  'Bh utan bygel,Bh,Underkläder,Framknäppt bh',
#  'Bh utan bygel,Bh-toppar,Bh,Bh utan kupstorlek,Underkläder',
#  'Bh utan bygel,Bh-toppar,Bh,Underkläder',
#  'Bh utan bygel,Bh-toppar,Framknäppt bh,Bh,Bh utan kupstorlek,Underkläder',
#  'Bh utan bygel,Bikini,Badkläder',
#  'Bh utan bygel,Body,Underkläder',
#  'Bh utan bygel,Bygel-bh,Bh,Underkläder',
#  'Bh utan bygel,Framknäppt bh,Bh,Underkläder',
#  'Bh utan bygel,Framknäppt bh,REA,Bh,Underkläder',
#  'Bh utan bygel,Korsetter,Body,Underkläder',
#  'Bh utan bygel,Korsetter,Underkläder',
#  'Bh utan bygel,REA,Bh,Underkläder',
#  'Bh utan bygel,Underkläder,Bh',
#  'Bh utan bygel,Underkläder,Sport-bh,Bh',
#  'Bh utan kupstorlek,Bikini,Badkläder',
#  'Bh utan kupstorlek,Bikini,Badkläder,Dam',
#  'Bh,Bygel-bh,Underkläder',
#  'Bh,Underkläder,Accessoarer,Bh-tillbehör',
#  'Bh,Underkläder,Bh-tillbehör',
#  'Bh,Underkläder,Bygel-bh',
#  'Bh,Underkläder,Linnen',
#  'Bh-toppar,Bh,Bh utan kupstorlek,Underkläder',
#  'Bikini,Badkläder',
#  'Bikini,Badkläder,Badshorts',
#  'Bikini,Badkläder,Dam',
#  'Bikini,Badkläder,Dam,Badshorts',
#  'Bikini,Dam',
#  'Blusar,Överdelar',
#  'Body,Underkläder',
#  'Broderitillbehör,Synhjälpmedel',
#  'Bygel-bh,Bh',
#  'Bygel-bh,Bh,Underkläder',
#  'Bygel-bh,Bikini,Badkläder',
#  'Bygel-bh,Body,Underkläder',
#  'Bygel-bh,Framknäppt bh,Bh,Underkläder',
#  'Bygel-bh,Underkläder',
#  'Byxor,Capribyxor,Nederdelar',
#  'Byxor,Fritidsbyxor,Fritidskläder,Dam',
#  'Byxor,Mjukisbyxor,Nederdelar,Mysplagg',
#  'Byxor,Nederdelar',
#  'Byxor,Nederdelar,Jeans',
#  'Byxor,Nederdelar,Leggings',
#  'Byxor,Nederdelar,REA',
#  'Byxor,Shorts,Nederdelar',
#  'Bädd',
#  'Bädd (linea),Bäddtillbehör',
#  'Bädd (linea),Påslakanset',
#  'Bädd,Bäddtillbehör,Bädd (linea)',
#  'Bädd,Bäddtillbehör,Lakan & örngott,Bädd (linea)',
#  'Bädd,Dynor & säten,Vardagshjälpmedel',
#  'Bädd,Inkontinens',
#  'Bädd,Lakan & örngott,Bädd (linea)',
#  'Bädd,Stödartiklar',
#  'Bädd,Vardagshjälpmedel',
#  'Bädd,Vardagshjälpmedel,Stödartiklar',
#  'Bädd,Vardagshjälpmedel,Stödartiklar,Bädd (linea)',
#  'Bädd,Värmeprodukter',
#  'Bäddtillbehör,Bädd (linea)',
#  'Bäddtillbehör,Bädd,Bädd (linea)',
#  'Bäddtillbehör,Bädd,Hälsa,Bädd (linea)',
#  'Bäddtillbehör,Bädd,Inkontinens,Bädd (linea)',
#  'Bäddtillbehör,Bädd,Värmeprodukter',
#  'Bäddtillbehör,Dynor & säten',
#  'Bäddtillbehör,Lakan & örngott,Bädd (linea)',
#  'Bäddtillbehör,Lakan & örngott,Bädd,Inkontinens',
#  'Bäddtillbehör,Lakan & örngott,Bädd,Inkontinens,Bädd (linea)',
#  'Capribyxor,Nederdelar',
#  'Capribyxor,Nederdelar,Byxor',
#  'Capribyxor,Nederdelar,Byxor,REA',
#  'Dam,Accessoarer,Kepsar & mössor',
#  'Dam,Baddräkter,Badkläder,Kjolbaddräkter',
#  'Dam,Badkläder,Tankini',
#  'Dam,Bh utan kupstorlek,Bikini,Badkläder',
#  'Dam,Bikini,Badkläder',
#  'Dam,Byxor,Nederdelar',
#  'Dam,Byxor,Nederdelar,REA',
#  'Dam,Skor,Skor & tofflor',
#  'Dekorationer,Juldekoration',
#  'Dukar',
#  'Dukar,Vaxdukar',
#  'Duschdraperier,Bad',
#  'Dynor & säten',
#  'Fotvård',
#  'Fotvård,Badrum/WC,Vardagshjälpmedel',
#  'Fotvård,Handvård',
#  'Fotvård,Handvård,Badrum/WC,Vardagshjälpmedel',
#  'Fotvård,Massage',
#  'Fotvård,Massage,Hälsa',
#  'Fotvård,Massage,Kroppsvård,Handvård',
#  'Fotvård,Massage,Värmeprodukter',
#  'Fotvård,Stödartiklar',
#  'Fotvård,Vardagshjälpmedel',
#  'Framknäppt bh,Bh,Underkläder',
#  'Framknäppt bh,Underkläder,Bh utan kupstorlek',
#  'Fritidskläder,Underställ,Nederdelar,Överdelar,Långkalsonger',
#  'Frottéhanddukar & badlakan',
#  'Frottéhanddukar & badlakan,Bad',
#  'Frottéhanddukar & badlakan,Kroppsvård,Badrum/WC,Barnrummet,Bad',
#  'Gardinbåge',
#  'Garn',
#  'Glas & porslin',
#  'Gånghjälpmedel',
#  'Gånghjälpmedel,Rollatorer',
#  'Halkskydd',
#  'Halkskydd,Gånghjälpmedel',
#  'Halkskydd,REA',
#  'Halkskydd,Strumpor,Underkläder,Halksockor',
#  'Handskar & vantar,Accessoarer',
#  'Handvård,REA',
#  'Handvård,Stödartiklar',
#  'Hattar,Accessoarer,Mössor & hattar',
#  'Herr,Sovkläder,Nattskjortor',
#  'Herr,Tofflor,Dam,Skor',
#  'Herr,Överdelar,T-shirts',
#  'Hobbyhörnan,Juldekoration,Pussel,Sällskapsspel',
#  'Hobbyhörnan,Pussel',
#  'Hobbyhörnan,Pussel 2000 bitar,Pussel',
#  'Hobbyhörnan,Pussel 500 bitar,REA',
#  'Hobbyhörnan,Pussel,Pussel 100 bitar',
#  'Hobbyhörnan,Pussel,Pussel 1000 bitar',
#  'Hobbyhörnan,Pussel,Pussel 1000 bitar,REA',
#  'Hobbyhörnan,Pussel,Pussel 1500 bitar',
#  'Hobbyhörnan,Pussel,Pussel 2000 bitar',
#  'Hobbyhörnan,Pussel,Pussel 275 bitar',
#  'Hobbyhörnan,Pussel,Pussel 350 bitar',
#  'Hobbyhörnan,Pussel,Pussel 500 bitar',
#  'Hobbyhörnan,Pussel,Pussel 500 bitar,Pussel 1000 bitar',
#  'Hobbyhörnan,Pussel,Pussel 500 bitar,REA',
#  'Hobbyhörnan,Pysselset',
#  'Hobbyhörnan,Sytillbehör',
#  'Hobbyhörnan,Sällskapsspel,Pussel',
#  'Hudvård,Handvård',
#  'Hudvård,Kroppsvård,Badrum/WC,Vardagshjälpmedel',
#  'Hudvård,Massage,Kroppsvård,Ansiktsvård',
#  'Hushåll övrigt,Dukar',
#  'Hushåll,Dukar',
#  'Hushåll,Halkskydd,Bad',
#  'Hushåll,Hushåll övrigt,Vardagshjälpmedel,Stödartiklar',
#  'Hushåll,Hushåll övrigt,Vardagshjälpmedel,Stödartiklar,Bädd (linea)',
#  'Hyllor & förvaring,Bad',
#  'Hyllor & förvaring,Bädd (linea)',
#  'Hällängder,Kanallängder',
#  'Inkontinens',
#  'Inkontinens,Badrum/WC',
#  'Inkontinens,Badshorts,Badkläder',
#  'Inkontinens,Dynor & säten',
#  'Inkontinens,Lust',
#  'Innerkuddar,Accessoarer,Bädd (linea)',
#  'Innerkuddar,Bädd (linea)',
#  'Innerkuddar,Bädd (linea),Kuddar',
#  'Intimvård',
#  'Intimvård,Inkontinens',
#  'Jackor,Ytterplagg',
#  'Juldekoration',
#  'Juldekoration,Dekorationer',
#  'Juldekoration,Julbelysning',
#  'Kalsonger,Underkläder',
#  'Kanalkappa',
#  'Kanalkappa,Kanallängder',
#  'Kanallängder',
#  'Kappor,Ytterplagg',
#  'Kjolar,Nederdelar',
#  'Klänningar',
#  'Klänningar,Badkläder,Strandklänning',
#  'Klänningar,Överdelar,Tunikor',
#  'Koftor,Överdelar',
#  'Konstväxter',
#  'Konstväxter,Accessoarer granar',
#  'Konstväxter,Julgranar/kransar/girlanger',
#  'Kroppsvård,Badrum/WC,Vardagshjälpmedel',
#  'Kroppsvård,Hälsa,Badrum/WC',
#  'Krukor,REA',
#  'Kuddar',
#  'Kökshanddukar',
#  'Kökshjälpmedel',
#  'Kökshjälpmedel,Badrum/WC,Vardagshjälpmedel',
#  'Kökshjälpmedel,Vardagshjälpmedel',
#  'Lakan & örngott,Bädd',
#  'Lakan & örngott,Bädd (linea)',
#  'Lakan & örngott,Bädd,Bädd (linea)',
#  'Linnen,Underkläder',
#  'Linnen,Underkläder,REA',
#  'Linnen,Överdelar,Dam',
#  'Ljusstakar & lyktor,Juldekoration',
#  'Ljusstakar & lyktor,Vaser',
#  'Lust',
#  'Långkalsonger,Underkläder',
#  'Löpare',
#  'Massage',
#  'Massage,Kroppsvård,Hälsa',
#  'Massage,REA,Hälsa',
#  'Medicin,Hälsa',
#  'Medicin,Hälsa,Vardagshjälpmedel',
#  'Minimizer,Bh utan bygel,Bh,Underkläder',
#  'Minimizer,Bh,Underkläder',
#  'Minimizer,Bygel-bh,Bh,Underkläder',
#  'Mjukisbyxor,Mysplagg',
#  'Mjukisbyxor,Mysplagg,Byxor',
#  'Mjukisbyxor,Nederdelar,Mysplagg',
#  'Morgonrockar,Sovkläder',
#  'Morgonrockar,Sovkläder,Morgonrockar & tofflor',
#  'Multibandskappa',
#  'Multibandslängder',
#  'Multibandslängder,Mörkläggningsgardiner',
#  'Mysplagg,Mjukisbyxor',
#  'Nattlinnen,Sovkläder',
#  'Nattlinnen,Sovkläder,Dam',
#  'Nattlinnen,Underkläder,Sovkläder',
#  'Nederdelar,Byxor',
#  'Nederdelar,Byxor,Leggings',
#  'Nederdelar,Byxor,Mjukisbyxor,Mysplagg',
#  'Nederdelar,Byxor,REA',
#  'Nederdelar,Leggings',
#  'Paint by numbers,Hobbyhörnan',
#  'Panellängder',
#  'Plädar',
#  'Protes-bh,Bh utan bygel,Bh,Underkläder',
#  'Protes-bh,Bh utan bygel,Bikini,Badkläder',
#  'Protes-bh,Bh utan bygel,Bikini,Badkläder,Dam',
#  'Protes-bh,Bh utan kupstorlek,Baddräkter,Badkläder',
#  'Protes-bh,Bh-toppar,Bh,Bh utan kupstorlek,Underkläder',
#  'Prydnadssaker,Bad',
#  'Prydnadssaker,Juldekoration',
#  'Prydnadssaker,Smycken,REA',
#  'Pussel,Pussel 100 bitar,Hobbyhörnan',
#  'Pussel,Pussel 1000 bitar,Hobbyhörnan',
#  'Pussel,Pussel 200 bitar,Hobbyhörnan',
#  'Pyjamas,Herr,Sovkläder',
#  'Pyjamas,Sovkläder',
#  'Påslakanset',
#  'REA',
#  'REA,Badrum/WC,Vardagshjälpmedel,Stödartiklar',
#  'REA,Bh utan bygel,Bh,Underkläder',
#  'REA,Bh utan bygel,Bh,Underkläder,Dam',
#  'REA,Byxor,Nederdelar',
#  'REA,Byxor,Nederdelar,Dam',
#  'REA,Hälsa,Vardagshjälpmedel',
#  'REA,Lust',
#  'REA,Medicin,Hälsa,Belysning',
#  'REA,Mjukisbyxor,Mysplagg',
#  'REA,Skor',
#  'REA,Skor,Skor & tofflor',
#  'REA,Synhjälpmedel',
#  'Rollatorer',
#  'Saxar',
#  'Servetter',
#  'Servetter,Picknick och uteliv',
#  'Shorts,Badkläder',
#  'Shorts,Nederdelar',
#  'Shorts,Underkläder,Byxor',
#  'Skjortor,Blusar,Överdelar',
#  'Skjortor,Herr',
#  'Skjortor,Överdelar',
#  'Skor',
#  'Skor & tofflor,Skor,Tofflor,Dam',
#  'Skor,Fotvård',
#  'Skor,Sandaler',
#  'Skor,Skor & tofflor',
#  'Skor,Skor & tofflor,Accessoarer',
#  'Skor,Skor & tofflor,Dam',
#  'Skotillbehör',
#  'Skotillbehör,Fotvård',
#  'Skotillbehör,Fotvård,REA',
#  'Skotillbehör,Vardagshjälpmedel',
#  'Sovkläder,Dam',
#  'Sovkläder,Morgonrockar & tofflor',
#  'Sovkläder,Pyjamas',
#  'Sport-bh,Bh utan bygel,Bh,Underkläder',
#  'Sport-bh,Bh utan bygel,Framknäppt bh,Bh,Underkläder',
#  'Sport-bh,Bh,Underkläder',
#  'Sport-bh,Bygel-bh,Bh,Underkläder',
#  'Sticktillbehör,Sytillbehör,Symaskiner och tillbehör',
#  'Strumpbyxor,Underkläder',
#  'Strumpbyxor,Underkläder,Nederdelar,Dam',
#  'Strumpor,Underkläder',
#  'Strumpor,Underkläder,Halksockor',
#  'Stödartiklar',
#  'Stödartiklar,Fotvård',
#  'Stödstrumpor',
#  'Stödstrumpor,Strumpor,Underkläder',
#  'Stödstrumpor,Strumpor,Underkläder,Halksockor',
#  'Stödstrumpor,Underkläder',
#  'Stödstrumpor,Underkläder,Strumpor',
#  'Symaskiner och tillbehör,Hushåll övrigt',
#  'Symaskiner och tillbehör,Sytillbehör',
#  'Symaskiner och tillbehör,Tvätt & skötsel,Hushåll övrigt',
#  'Synhjälpmedel,Belysning',
#  'Synhjälpmedel,Belysning,Vardagshjälpmedel',
#  'Synhjälpmedel,Vardagshjälpmedel,Belysning',
#  'Sytillbehör,Gardintillbehör,Gardiner (linea)',
#  'Sytillbehör,Symaskiner och tillbehör',
#  'Sytillbehör,Symaskiner och tillbehör,Hushåll övrigt',
#  'Sytillbehör,Vardagshjälpmedel',
#  'Sytillbehör,Väskor & fodral,Accessoarer,Symaskiner och tillbehör,Hyllor & förvaring',
#  'T-shirt-bh,Bh utan bygel,Bh,Underkläder',
#  'Tabletter/underlägg/brickor',
#  'Tavlor,Broderikit',
#  'Tofflor,Skor',
#  'Tofflor,Skor,Fotvård',
#  'Tofflor,Värmeprodukter,Skor & tofflor',
#  'Toppar,Underkläder',
#  'Toppar,Överdelar',
#  'Toppar,Överdelar,Mysplagg',
#  'Toppar,Överdelar,T-shirts',
#  'Trosor,Underkläder,Gördlar',
#  'Träning & motion',
#  'Träning & motion,Gånghjälpmedel',
#  'Träning & motion,Handvård,Massage,Hälsa',
#  'Träning & motion,Hälsa',
#  'Träning & motion,Massage',
#  'Träning & motion,REA,Hälsa',
#  'Träningskläder,Träningsbyxor,Byxor',
#  'Tröjor,Överdelar',
#  'Tunikor,Överdelar',
#  'Tvätt & skötsel,Hushåll övrigt,Vardagshjälpmedel',
#  'Tvätt & skötsel,Symaskiner och tillbehör',
#  'Tvätt & skötsel,Symaskiner och tillbehör,Hushåll övrigt',
#  'Tvätt & skötsel,Sytillbehör,Vardagshjälpmedel',
#  'Tvätt & skötsel,Vardagshjälpmedel',
#  'Tvätt & skötsel,Vardagshjälpmedel,Hushåll övrigt',
#  'Tvätt & skötsel,Vardagshjälpmedel,Symaskiner och tillbehör,Hushåll övrigt',
#  'Täcken,Bädd (linea)',
#  'Täcken,Bäddtillbehör,Bädd (linea)',
#  'Täcken,Bäddtillbehör,Bädd (linea),Kuddar,Innerkuddar',
#  'Underkjolar,Underkläder',
#  'Underkläder,Accessoarer,Bh-tillbehör',
#  'Underkläder,Bh utan bygel',
#  'Underkläder,Bh utan bygel,Bh',
#  'Underkläder,Bh utan bygel,Body',
#  'Underkläder,Bh,Bygel-bh',
#  'Underkläder,Bh,Framknäppt bh,Bh utan bygel',
#  'Underkläder,Bh,Minimizer',
#  'Underkläder,Bh,Sport-bh',
#  'Underkläder,Bygel-bh',
#  'Underkläder,Bygel-bh,Bh',
#  'Underkläder,Bygel-bh,Sport-bh',
#  'Underkläder,Dam,Trosor',
#  'Underkläder,Gördlar',
#  'Underkläder,Kalsonger',
#  'Underkläder,Linnen',
#  'Underkläder,Linnen,Bh',
#  'Underkläder,Mamelucker',
#  'Underkläder,Sport-bh,Bh',
#  'Underkläder,Sport-bh,Bh utan bygel,Bh',
#  'Underkläder,Strumpor',
#  'Underkläder,Trosor',
#  'Underkläder,Trosor & gördlar',
#  'Underkläder,Trosor & gördlar,Trosor',
#  'Underkläder,Trosor,Byxor',
#  'Underkläder,Trosor,Gördlar',
#  'Underkläder,Trosor,Mamelucker',
#  'Underkläder,Underklänningar',
#  'Underkläder,Undertröjor',
#  'Vardagshjälpmedel',
#  'Vardagshjälpmedel,Dynor & säten',
#  'Vardagshjälpmedel,Strumpor',
#  'Vardagshjälpmedel,Synhjälpmedel,Belysning',
#  'Vaxdukar',
#  'Vaxdukar,Dukar',
#  'Virknålar,Vardagshjälpmedel',
#  'Värmeprodukter',
#  'Väskor,Accessoarer',
#  'Väskor,Hushåll övrigt,Accessoarer',
#  'Väskor,Vardagshjälpmedel',
#  'Ytterplagg,Jackor',
#  'Ytterplagg,Kappor',
#  'unknown',
#  'Öljettkappa',
#  'Överdelar',
#  'Överdelar,Blusar',
#  'Överdelar,Blusar,Skjortor',
#  'Överdelar,Koftor',
#  'Överdelar,Skjortor',
#  'Överdelar,T-shirts',
#  'Överdelar,Toppar',
#  'Överdelar,Tröjor',
#  'Överdelar,Tunikor',
#  'Överdelar,Tunikor,Skjortor',
#  'Överdelar,Ytterplagg,Fleecejackor',
#  'Överdelar,Ytterplagg,Kappor']

# %%
def normalize_brand(brand):
    # Strip leading/trailing spaces, reduce multiple spaces to one, sentence case
    if isinstance(brand, str):
        brand_clean = ' '.join(brand.strip().split())
        return brand_clean.capitalize()
    return brand

pairs['brand'] = pairs['brand'].apply(normalize_brand)

# %%
import pandas as pd
import pyarrow.parquet as pq
import pyarrow as pa

def cat_to_set(s):
    if pd.isna(s): return set()
    toks = {t.strip().lower() for t in str(s).split(",") if t.strip()}
    return {t for t in toks if t != "unknown"}

def preprocess(pairs: pd.DataFrame):
    df = pairs.copy()
    df["brand_norm"] = df["brand"].astype(str).str.strip().str.lower()
    is_unknown = df["brand_norm"].eq("unknown")
    skipped = int(is_unknown.sum())
    df = df.loc[~is_unknown].copy()
    df["cat_set"] = df["category"].map(cat_to_set)
    return df, skipped

def build_recs(filtered_pairs: pd.DataFrame, min_recs=4, max_recs=10):
    recs, insufficient = {}, 0
    for _, g in filtered_pairs.groupby("brand_norm", sort=False):
        g = g.sort_values("transactions", ascending=False)
        cat_map = g["cat_set"].to_dict()
        for idx, row in g.iterrows():
            gid = str(row["groupId"])
            my_cats = row["cat_set"]
            if not my_cats: 
                insufficient += 1
                continue
            mask = (
                (g["groupId"].astype(str) != gid)
                & (g.index != idx)
                & g.index.map(lambda j: not my_cats.isdisjoint(cat_map[j]))
            )
            tops = g.loc[mask, "groupId"].astype(str).head(max_recs).tolist()
            if len(tops) >= min_recs:
                recs[gid] = {f"Top {i+1}": t for i, t in enumerate(tops)}
            else:
                insufficient += 1
    rows = [{"Product ID": k, **v} for k, v in recs.items()]
    df = pd.DataFrame(rows)
    if not df.empty:
        ordered = ["Product ID"] + [c for i in range(1, max_recs + 1) if (c := f"Top {i}") in df.columns]
        df = df[ordered]
    return df, insufficient

def save_parquet(df: pd.DataFrame, path: str):
    table = pa.Table.from_pandas(df)
    pq.write_table(table, path)

def run(pairs: pd.DataFrame, min_recs=4, max_recs=10, out_path="/workspace/data/processed/top_same_brand.parquet"):
    filtered, skipped = preprocess(pairs)
    export_df, insufficient = build_recs(filtered, min_recs=min_recs, max_recs=max_recs)
    save_parquet(export_df, out_path)
    print(f"Skipped {skipped} rows due to Unknown brand")
    print(f"Removed {insufficient} groupIds due to having fewer than {min_recs} recommendations")
    print(f"Saved {len(export_df)} rows to {out_path}")
    return export_df

# Example:
export_df = run(pairs, min_recs=4, max_recs=10)
# Out:
# Skipped 40 rows due to Unknown brand
# Removed 161 groupIds due to having fewer than 4 recommendations
# Saved 1262 rows to /workspace/data/processed/top_same_brand_and_category.parquet
