# %%
import pandas as pd
articles = pd.read_csv("../data/external/products.csv", dtype='string')

# %%
# number of unique groupid
print(articles['groupId'].nunique())
# Out:
# 9177

# %%
{len(articles)}
# Out:
# {110120}

# %%
articles = articles.drop(columns=[
    'status', 'incommingQuantity', 'length', 'width', 'height', 'weight',
    'fabricId', 'fabric', 'description', 'colorId', 'color',
    'sizeId', 'size', 'audience', 'audienceId', 'publishedDate', 'quantity'
])

# %%
articles.sample(10)
# Out:
#                 sku groupId brandId                              name  \
# 77990   260919-4085  260919      50                  Bh med dragkedja
# 36190   213777-0054  213777    <NA>                              Topp
# 90605   260364-4850  260364    <NA>                        Alushousut
# 39103   210764-000l  210764     126                    Flanellskjorta
# 54142   261122-0052  260533       3                  Trosgördel Clara
# 109121  262717-4095  260596      80               Bh utan bygel Stars
# 64793   267402-G080  267435       3                    Bygel-bh Selma
# 89345   260303-C095  260303      80                    Sport-bh Magic
# 3388         432060  432060     189  Pussel Tomens verkstad 500 bitar
# 85583   260424-C115  260424     109            Bomulls-bh Louise skin
#
#               brand                                           category  \
# 77990     Miss Mary                                              Bh,Bh
# 36190          <NA>                                                REA
# 90605          <NA>                                               <NA>
# 39103        Åshild                                      Skjortor,Herr
# 54142         Anita                                Underkläder,Gördlar
# 109121     Swegmark  Bh utan bygel,Bh utan bygel,Bh,Bh,Underkläder,...
# 64793         Anita                   Bh,Bygel-bh,Underkläder,Bygel-bh
# 89345      Swegmark  Sport-bh,Bh utan bygel,Bh,Underkläder,Sport-bh...
# 3388    Cobble Hill  Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pus...
# 85583        Louise  Bh utan bygel,Framknäppt bh,Bh,Bh utan bygel,F...
#
#                                  categoryId priceSEK priceEUR priceNOK  \
# 77990                                 27,27      299     36.9      299
# 36190                                   110      218     21.9      218
# 90605                                  <NA>      209     24.9      209
# 39103                              1519,162      349     34.9      349
# 54142                               19,1797      429    44.95      499
# 109121              50,50,27,27,19,19,50,50      479     44.9      549
# 64793                         27,223,19,223      849    82.95      899
# 89345                   618,50,27,19,618,50      629     62.9      749
# 3388    172,172,172,365,365,365,499,499,499      249     22.9      298
# 85583                      50,189,27,50,189      189     19.9      189
#
#        priceDKK forSale
# 77990       299    <NA>
# 36190       218    <NA>
# 90605       209    <NA>
# 39103       349       1
# 54142       329    <NA>
# 109121      429       1
# 64793       599    <NA>
# 89345       579       1
# 3388        219       1
# 85583       189    <NA>

# %%
#count proportion of missing values in each column
articles.isnull().mean()
# Out:
# sku           0.000000
# groupId       0.000009
# brandId       0.183300
# name          0.013031
# brand         0.183300
# category      0.052370
# categoryId    0.052370
# priceSEK      0.001571
# priceEUR      0.006402
# priceNOK      0.006220
# priceDKK      0.006720
# forSale       0.699155
# dtype: float64

# %% [markdown]
# Removing bugs

# %%
# Remove rows where all price columns are NA
price_columns = ['priceSEK', 'priceEUR', 'priceNOK', 'priceDKK']
articles = articles[~articles[price_columns].isna().all(axis=1)]
print(f"Rows after removing all-prices-NA: {len(articles)}")
# Out:
# Rows after removing all-prices-NA: 110099

# %% [markdown]
# # Category

# %%
# Show unique categoryIds per category (excluding NA)
cat_stats = articles[articles['categoryId'].notna()].groupby('category')['categoryId'].agg(['unique', 'count'])
print(f"{'category':50} {'categoryIds':40} count")
for cat, (ids, cnt) in cat_stats.iterrows():
    # Format the list of ids as a string, not using a format specifier for the list
    ids_str = str(list(ids))
    print(f"{cat:50} {ids_str:40} {cnt}")

# Categories with >1 unique categoryId
multi_cat = cat_stats['unique'].apply(lambda x: sum(pd.notna(x)) > 1)
if multi_cat.any():
    print("\nCategories with >1 categoryId:")
    for cat, ids in cat_stats.loc[multi_cat, 'unique'].items():
        print(f"{cat}: {[i for i in ids if pd.notna(i)]}")
else:
    print("\nNo category has >1 categoryId.")

print(f"\nArticles without categoryId: {articles['categoryId'].isna().sum()}")
print(f"Articles without category: {articles['category'].isna().sum()}")
# Out:
# category                                           categoryIds                              count
# Accessoarer                                        ['454']                                  5
# Accessoarer,Accessoarer,Bh,Bh,Underkläder,Underkläder,Bh-tillbehör,Bh-tillbehör ['454,454,27,27,19,19,691,691']          3
# Accessoarer,Accessoarer,Handskar & vantar,Handskar & vantar ['454,454,1415,1415']                    1
# Accessoarer,Accessoarer,Kepsar & mössor,Kepsar & mössor ['454,454,1447,1447']                    3
# Accessoarer,Halsdukar & sjalar                     ['454,7']                                1
# Accessoarer,Handskar & vantar                      ['454,1415']                             5
# Accessoarer,Herr,Kepsar & mössor                   ['454,162,1447']                         3
# Accessoarer,Kepsar & mössor                        ['454,1447']                             15
# Accessoarer,Kepsar & mössor,Accessoarer,Kepsar & mössor ['454,1447,454,1447']                    2
# Accessoarer,Väskor                                 ['454,200']                              1
# Ansiktsvård                                        ['2408']                                 4
# Bad,Bad,Duschdraperier,Duschdraperier              ['646,646,338,338']                      3
# Bad,Bad,Frottéhanddukar & badlakan,Frottéhanddukar & badlakan ['646,646,262,262']                      12
# Bad,Bad,Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,Bad,Bad,Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,Bad,Bad,Frottéhanddukar & badlakan,Frottéhanddukar & badlakan ['646,646,262,262,646,646,262,262,646,646,262,262'] 3
# Baddräkter,Baddräkter,Badkläder,Badkläder          ['469,469,470,470']                      9
# Baddräkter,Badkläder                               ['469,470']                              799
# Baddräkter,Badkläder,Baddräkter,Badkläder          ['469,470,469,470']                      2
# Baddräkter,Badkläder,Dam                           ['469,470,471']                          268
# Baddräkter,Dam                                     ['469,471']                              12
# Baddräkter,Tankini                                 ['469,1835']                             21
# Badkläder                                          ['470']                                  76
# Badkläder,Baddräkter                               ['470,469']                              168
# Badkläder,Baddräkter,Baddräkter                    ['470,469,469']                          12
# Badkläder,Baddräkter,Badkläder,Baddräkter          ['470,469,470,469']                      26
# Badkläder,Baddräkter,Kjolbaddräkter                ['470,469,2354']                         33
# Badkläder,Badkläder,Baddräkter,Baddräkter          ['470,470,469,469']                      92
# Badkläder,Badshorts                                ['470,2371']                             35
# Badkläder,Badshorts,Herr                           ['470,2371,162']                         10
# Badkläder,Bikini                                   ['470,736']                              435
# Badkläder,Dam                                      ['470,471']                              42
# Badkläder,Dam,Tankini                              ['470,471,1835']                         9
# Badkläder,Sarong                                   ['470,2362']                             6
# Badkläder,Strandklänning                           ['470,2010']                             1
# Badkläder,Tankini                                  ['470,1835']                             13
# Badrum/WC                                          ['481']                                  18
# Badrum/WC,Badrum/WC                                ['481,481']                              1
# Badrum/WC,Badrum/WC,Ansiktsvård,Ansiktsvård        ['481,481,2408,2408']                    1
# Badrum/WC,Badrum/WC,Duschdraperier,Duschdraperier,Bad,Bad ['481,481,338,338,646,646']              3
# Badrum/WC,Badrum/WC,Vardagshjälpmedel,Vardagshjälpmedel,Stödartiklar,Stödartiklar ['481,481,497,497,1460,1460']            4
# Badrum/WC,Vardagshjälpmedel                        ['481,497']                              1
# Badrumsmattor,Badrum/WC                            ['398,481']                              19
# Badrumsmattor,Badrumsmattor                        ['398,398']                              5
# Badrumsmattor,Badrumsmattor,Bad,Bad                ['398,398,646,646']                      78
# Badrumsmattor,Badrumsmattor,Badrum/WC,Badrum/WC    ['398,398,481,481']                      3
# Badrumsmattor,Badrumstillbehör,Kroppsvård          ['398,339,1079']                         3
# Badrumstillbehör                                   ['339']                                  1
# Badrumstillbehör,Badrum/WC,Speglar                 ['339,481,859']                          1
# Badrumstillbehör,Badrumstillbehör,Bad,Bad          ['339,339,646,646']                      8
# Badrumstillbehör,Badrumstillbehör,Badrum/WC,Badrum/WC ['339,339,481,481']                      1
# Badrumstillbehör,Badrumstillbehör,Fotvård,Fotvård,Badrum/WC,Badrum/WC,Handvård,Handvård ['339,339,1981,1981,481,481,1639,1639']  1
# Badrumstillbehör,Badrumstillbehör,Kökshjälpmedel,Kökshjälpmedel,Hudvård,Hudvård,Handvård,Handvård,Kroppsvård,Kroppsvård,Badrum/WC,Badrum/WC,Vardagshjälpmedel,Vardagshjälpmedel,Bad,Bad ['339,339,1418,1418,1638,1638,1639,1639,1079,1079,481,481,497,497,646,646'] 1
# Badrumstillbehör,REA,Badrum/WC,Vardagshjälpmedel   ['339,110,481,497']                      1
# Badrumstillbehör,REA,Kroppsvård                    ['339,110,1079']                         2
# Badrumstillbehör,Vardagshjälpmedel                 ['339,497']                              1
# Badskor,Badkläder                                  ['2412,470']                             12
# Batteridrivna ljus,Batteridrivna ljus,Batteridrivna ljus ['461,461,461']                          2
# Batteridrivna ljus,Batteridrivna ljus,Batteridrivna ljus,Belysning,Belysning,Belysning ['461,461,461,460,460,460']              1
# Belysning                                          ['460']                                  1
# Belysning,Barnrummet,Natt & garderobslampor        ['460,195,887']                          1
# Belysning,Belysning,Barnrummet,Barnrummet,Natt & garderobslampor,Natt & garderobslampor ['460,460,195,195,887,887']              5
# Belysning,Belysning,Belysning,Batteridrivna ljus,Batteridrivna ljus,Batteridrivna ljus ['460,460,460,461,461,461']              6
# Belysning,Belysning,Belysning,Batteridrivna ljus,Batteridrivna ljus,Batteridrivna ljus,REA,REA,REA ['460,460,460,461,461,461,110,110,110']  11
# Belysning,Belysning,Belysning,Bordslampor,Bordslampor,Bordslampor,REA,REA,REA ['460,460,460,291,291,291,110,110,110']  1
# Belysning,Belysning,Belysning,Fönsterlampor,Fönsterlampor,Fönsterlampor ['460,460,460,215,215,215']              1
# Belysning,Belysning,Belysning,Hushåll övrigt,Hushåll övrigt,Hushåll övrigt,Vardagshjälpmedel,Vardagshjälpmedel,Vardagshjälpmedel ['460,460,460,392,392,392,497,497,497']  1
# Belysning,Belysning,Belysning,Vardagshjälpmedel,Vardagshjälpmedel,Vardagshjälpmedel,Batterier,Batterier,Batterier ['460,460,460,497,497,497,863,863,863']  3
# Belysning,Belysning,Bordslampor,Bordslampor,REA,REA,REA,REA ['460,460,291,291,110,110,110,110']      4
# Bh                                                 ['27']                                   1908
# Bh utan bygel,Bad- & strandkläder,Bh utan bygel    ['50,306,50']                            6
# Bh utan bygel,Baddräkter,Badkläder,Bh utan bygel   ['50,469,470,50']                        144
# Bh utan bygel,Bh utan bygel                        ['50,50']                                78
# Bh utan bygel,Bh utan bygel,Bh utan bygel,Bh,Bh,Bh,Underkläder,Underkläder,Underkläder,Bh utan bygel,Bh utan bygel,Bh utan bygel ['50,50,50,27,27,27,19,19,19,50,50,50']  200
# Bh utan bygel,Bh utan bygel,Bh utan bygel,Framknäppt bh,Framknäppt bh,Framknäppt bh,Bh,Bh,Bh,Underkläder,Underkläder,Underkläder,Bh utan bygel,Bh utan bygel,Bh utan bygel,Framknäppt bh,Framknäppt bh,Framknäppt bh ['50,50,50,189,189,189,27,27,27,19,19,19,50,50,50,189,189,189'] 3
# Bh utan bygel,Bh utan bygel,Bh,Bh,Underkläder,Underkläder ['50,50,27,27,19,19']                    8
# Bh utan bygel,Bh utan bygel,Bh,Bh,Underkläder,Underkläder,Bh utan bygel,Bh utan bygel ['50,50,27,27,19,19,50,50']              6020
# Bh utan bygel,Bh utan bygel,Bh,Bh,Underkläder,Underkläder,Bh utan bygel,Bh utan bygel,Linnen,Linnen ['50,50,27,27,19,19,50,50,154,154']      49
# Bh utan bygel,Bh utan bygel,Bh-toppar,Bh-toppar,Framknäppt bh,Framknäppt bh,Bh,Bh,Bh utan kupstorlek,Bh utan kupstorlek,Underkläder,Underkläder,Bh utan bygel,Bh utan bygel,Bh-toppar,Bh-toppar,Framknäppt bh,Framknäppt bh,Bh utan kupstorlek,Bh utan kupstorlek ['50,50,40,40,189,189,27,27,41,41,19,19,50,50,40,40,189,189,41,41'] 21
# Bh utan bygel,Bh utan bygel,Bh-toppar,Bh-toppar,Framknäppt bh,Framknäppt bh,Underkläder,Underkläder,Bh utan bygel,Bh utan bygel,Bh-toppar,Bh-toppar,Framknäppt bh,Framknäppt bh ['50,50,40,40,189,189,19,19,50,50,40,40,189,189'] 72
# Bh utan bygel,Bh utan bygel,Body,Body,Underkläder,Underkläder,Bh utan bygel,Bh utan bygel ['50,50,450,450,19,19,50,50']            97
# Bh utan bygel,Bh utan bygel,Framknäppt bh,Framknäppt bh,Bh,Bh,Underkläder,Underkläder,Bh utan bygel,Bh utan bygel,Framknäppt bh,Framknäppt bh ['50,50,189,189,27,27,19,19,50,50,189,189'] 328
# Bh utan bygel,Bh utan bygel,Framknäppt bh,Framknäppt bh,REA,REA,Bh,Bh,Underkläder,Underkläder,Bh utan bygel,Bh utan bygel,Framknäppt bh,Framknäppt bh ['50,50,189,189,110,110,27,27,19,19,50,50,189,189'] 114
# Bh utan bygel,Bh utan bygel,REA,REA,Bh,Bh,Underkläder,Underkläder,Bh utan bygel,Bh utan bygel ['50,50,110,110,27,27,19,19,50,50']      72
# Bh utan bygel,Bh utan kupstorlek,Bikini,Badkläder,Dam,Bh utan bygel,Bh utan kupstorlek ['50,41,736,470,471,50,41']              8
# Bh utan bygel,Bh,Bh utan bygel                     ['50,27,50']                             6798
# Bh utan bygel,Bh,Sport-bh,Bygel-bh,Underkläder     ['50,27,618,223,19']                     208
# Bh utan bygel,Bh,Underkläder                       ['50,27,19']                             349
# Bh utan bygel,Bh,Underkläder,Bh utan bygel         ['50,27,19,50']                          11559
# Bh utan bygel,Bh,Underkläder,Bh utan bygel,Bh utan bygel,Bh,Underkläder,Bh utan bygel ['50,27,19,50,50,27,19,50']              2
# Bh utan bygel,Bh,Underkläder,Bh utan bygel,Linnen  ['50,27,19,50,154']                      49
# Bh utan bygel,Bh,Underkläder,Framknäppt bh         ['50,27,19,189']                         56
# Bh utan bygel,Bh-toppar,Bh,Bh utan bygel,Bh-toppar ['50,40,27,50,40']                       28
# Bh utan bygel,Bh-toppar,Bh,Bh utan kupstorlek,Underkläder,Bh utan bygel,Bh-toppar,Bh utan kupstorlek ['50,40,27,41,19,50,40,41']              22
# Bh utan bygel,Bh-toppar,Bh,Underkläder,Bh utan bygel,Bh-toppar ['50,40,27,19,50,40']                    56
# Bh utan bygel,Bh-toppar,Framknäppt bh,Bh,Bh utan bygel,Bh-toppar,Framknäppt bh ['50,40,189,27,50,40,189']               95
# Bh utan bygel,Bh-toppar,Framknäppt bh,Bh,Underkläder,Bh utan bygel,Bh-toppar,Framknäppt bh ['50,40,189,27,19,50,40,189']            23
# Bh utan bygel,Bh-toppar,REA,Bh,Underkläder,Bh utan bygel,Bh-toppar ['50,40,110,27,19,50,40']                4
# Bh utan bygel,Bh-toppar,REA,Bh,Underkläder,Trosor,Bh utan bygel,Bh-toppar ['50,40,110,27,19,20,50,40']             4
# Bh utan bygel,Bikini,Badkläder                     ['50,736,470']                           28
# Bh utan bygel,Bikini,Badkläder,Bh utan bygel       ['50,736,470,50']                        143
# Bh utan bygel,Bikini,Badkläder,Dam,Bh utan bygel   ['50,736,470,471,50']                    20
# Bh utan bygel,Body,Bh utan bygel                   ['50,450,50']                            212
# Bh utan bygel,Body,Underkläder                     ['50,450,19']                            8
# Bh utan bygel,Body,Underkläder,Bh utan bygel       ['50,450,19,50']                         812
# Bh utan bygel,Body,Underkläder,Bh utan bygel,Body,Underkläder ['50,450,19,50,450,19']                  1
# Bh utan bygel,Bygel-bh,Bh,Underkläder,Bh utan bygel,Bygel-bh ['50,223,27,19,50,223']                  410
# Bh utan bygel,Bygel-bh,Bh,Underkläder,Bh utan bygel,Bygel-bh,Bh utan bygel,Bygel-bh,Bh,Underkläder,Bh utan bygel,Bygel-bh ['50,223,27,19,50,223,50,223,27,19,50,223'] 6
# Bh utan bygel,Framknäppt bh,Bh,Bh utan bygel,Framknäppt bh ['50,189,27,50,189']                     181
# Bh utan bygel,Framknäppt bh,Bh,Underkläder,Bh utan bygel,Framknäppt bh ['50,189,27,19,50,189']                  653
# Bh utan bygel,Korsetter,Body,Underkläder,Bh utan bygel ['50,934,450,19,50']                     124
# Bh utan bygel,Korsetter,Underkläder,Bh utan bygel  ['50,934,19,50']                         150
# Bh utan bygel,REA,Bh utan bygel                    ['50,110,50']                            22
# Bh utan bygel,REA,Bh,Bh utan bygel                 ['50,110,27,50']                         391
# Bh utan bygel,Sport-bh,Bygel-bh,Bh,Underkläder,Bh utan bygel,Sport-bh,Bygel-bh ['50,618,223,27,19,50,618,223']          41
# Bh utan bygel,Underkläder,Bh                       ['50,19,27']                             66
# Bh utan bygel,Underkläder,Framknäppt bh,Bh,Bh utan bygel,Framknäppt bh ['50,19,189,27,50,189']                  91
# Bh utan bygel,Underkläder,Sport-bh,Bh,Bh utan bygel,Sport-bh ['50,19,618,27,50,618']                  112
# Bh utan kupstorlek,Bikini,Badkläder,Bh utan kupstorlek ['41,736,470,41']                        42
# Bh utan kupstorlek,Bikini,Badkläder,Dam            ['41,736,470,471']                       28
# Bh utan kupstorlek,Bikini,Badkläder,Dam,Bh utan kupstorlek ['41,736,470,471,41']                    70
# Bh,Balconett-bh,Underkläder,Balconett-bh           ['27,2322,19,2322']                      24
# Bh,Bh                                              ['27,27']                                477
# Bh,Bh,Bygel-bh,Bygel-bh,Underkläder,Underkläder    ['27,27,223,223,19,19']                  2
# Bh,Bh,Underkläder,Underkläder,Accessoarer,Accessoarer,Bh-tillbehör,Bh-tillbehör ['27,27,19,19,454,454,691,691']          5
# Bh,Bygel-bh,Underkläder                            ['27,223,19']                            363
# Bh,Bygel-bh,Underkläder,Bygel-bh                   ['27,223,19,223']                        170
# Bh,Sport-bh,Underkläder                            ['27,618,19']                            25
# Bh,Underkläder,Accessoarer,Bh-tillbehör            ['27,19,454,691']                        2
# Bh,Underkläder,Bh-tillbehör                        ['27,19,691']                            2
# Bh,Underkläder,Bygel-bh                            ['27,19,223']                            34
# Bh,Underkläder,Linnen                              ['27,19,154']                            28
# Bh-toppar,Bh,Bh utan kupstorlek,Underkläder,Bh-toppar,Bh utan kupstorlek ['40,27,41,19,40,41']                    17
# Bh-toppar,Bh,Bh-toppar                             ['40,27,40']                             14
# Bh-toppar,Bh-toppar,Bh,Bh,Bh utan kupstorlek,Bh utan kupstorlek,Underkläder,Underkläder,Bh-toppar,Bh-toppar,Bh utan kupstorlek,Bh utan kupstorlek ['40,40,27,27,41,41,19,19,40,40,41,41']  36
# Bh-toppar,Bh-toppar,Bh-toppar,Bh,Bh,Bh,Bh utan kupstorlek,Bh utan kupstorlek,Bh utan kupstorlek,Underkläder,Underkläder,Underkläder,Bh-toppar,Bh-toppar,Bh-toppar,Bh utan kupstorlek,Bh utan kupstorlek,Bh utan kupstorlek ['40,40,40,27,27,27,41,41,41,19,19,19,40,40,40,41,41,41'] 4
# Bikini,Badkläder                                   ['736,470']                              470
# Bikini,Badkläder,Badshorts                         ['736,470,2371']                         21
# Bikini,Badkläder,Dam                               ['736,470,471']                          305
# Bikini,Badkläder,Dam,Badshorts                     ['736,470,471,2371']                     5
# Bikini,Dam                                         ['736,471']                              11
# Blusar                                             ['1533']                                 9
# Blusar,Blusar,Skjortor,Skjortor,Överdelar,Överdelar ['1533,1533,1519,1519,1552,1552']        31
# Blusar,Blusar,Överdelar,Överdelar                  ['1533,1533,1552,1552']                  38
# Blusar,Blusar,Överdelar,Överdelar,Skjortor,Skjortor ['1533,1533,1552,1552,1519,1519']        9
# Blusar,Överdelar                                   ['1533,1552']                            9
# Body                                               ['450']                                  712
# Body,Body,Underkläder,Underkläder                  ['450,450,19,19']                        56
# Body,Linnen                                        ['450,154']                              32
# Body,Underkläder                                   ['450,19']                               225
# Bomulls- & trasmattor                              ['275']                                  8
# Broderier utan garn,Broderier utan garn,Broderier utan garn ['459,459,459']                          1
# Broderitillbehör,Broderitillbehör,Broderitillbehör ['474,474,474']                          1
# Broderitillbehör,Broderitillbehör,Broderitillbehör,Synhjälpmedel,Synhjälpmedel,Synhjälpmedel ['474,474,474,217,217,217']              1
# Bygel-bh,Bh utan bygel,Strumpor,Bh,Herr,Bygel-bh,Bh utan bygel ['223,50,95,27,162,223,50']              45
# Bygel-bh,Bh,Balconett-bh,Bygel-bh,Balconett-bh     ['223,27,2322,223,2322']                 87
# Bygel-bh,Bh,Balconett-bh,Underkläder,Bygel-bh,Balconett-bh ['223,27,2322,19,223,2322']              48
# Bygel-bh,Bh,Bygel-bh                               ['223,27,223']                           3161
# Bygel-bh,Bh,Bygel-bh,Underkläder                   ['223,27,223,19']                        35
# Bygel-bh,Bh,Underkläder                            ['223,27,19']                            184
# Bygel-bh,Bh,Underkläder,Bygel-bh                   ['223,27,19,223']                        7571
# Bygel-bh,Bh,Underkläder,Bygel-bh,Bh,Underkläder    ['223,27,19,223,27,19']                  21
# Bygel-bh,Bikini,Badkläder                          ['223,736,470']                          50
# Bygel-bh,Bikini,Badkläder,Bygel-bh                 ['223,736,470,223']                      456
# Bygel-bh,Bikini,Badkläder,Bygel-bh,Bygel-bh,Bikini,Badkläder,Bygel-bh ['223,736,470,223,223,736,470,223']      11
# Bygel-bh,Bikini,Badkläder,Dam,Bygel-bh             ['223,736,470,471,223']                  300
# Bygel-bh,Body,Underkläder,Bygel-bh                 ['223,450,19,223']                       50
# Bygel-bh,Bygel-bh                                  ['223,223']                              208
# Bygel-bh,Bygel-bh,Bh,Bh,Underkläder,Underkläder    ['223,223,27,27,19,19']                  55
# Bygel-bh,Bygel-bh,Bh,Bh,Underkläder,Underkläder,Bygel-bh,Bygel-bh ['223,223,27,27,19,19,223,223']          1546
# Bygel-bh,Bygel-bh,Bh,Bh,Underkläder,Underkläder,Bygel-bh,Bygel-bh,Bh,Bh,Underkläder,Underkläder ['223,223,27,27,19,19,223,223,27,27,19,19'] 17
# Bygel-bh,Bygel-bh,Bh,Bh,Underkläder,Underkläder,Bygel-bh,Bygel-bh,Bh,Bh,Underkläder,Underkläder,Bygel-bh,Bygel-bh,Bh,Bh,Underkläder,Underkläder ['223,223,27,27,19,19,223,223,27,27,19,19,223,223,27,27,19,19'] 3
# Bygel-bh,Bygel-bh,Bh,Bh,Underkläder,Underkläder,Bygel-bh,Bygel-bh,Bygel-bh,Bygel-bh,Bh,Bh,Underkläder,Underkläder,Bygel-bh,Bygel-bh ['223,223,27,27,19,19,223,223,223,223,27,27,19,19,223,223'] 3
# Bygel-bh,Bygel-bh,Body,Body,Underkläder,Underkläder,Bygel-bh,Bygel-bh ['223,223,450,450,19,19,223,223']        140
# Bygel-bh,Bygel-bh,Bygel-bh,Bh,Bh,Bh,Underkläder,Underkläder,Underkläder,Bygel-bh,Bygel-bh,Bygel-bh ['223,223,223,27,27,27,19,19,19,223,223,223'] 95
# Bygel-bh,Framknäppt bh,Bh,Underkläder              ['223,189,27,19']                        127
# Bygel-bh,Framknäppt bh,Bh,Underkläder,Bygel-bh,Framknäppt bh ['223,189,27,19,223,189']                1603
# Bygel-bh,Framknäppt bh,REA,Bh,Underkläder,Bygel-bh,Framknäppt bh ['223,189,110,27,19,223,189']            102
# Bygel-bh,Korsetter,Bygel-bh                        ['223,934,223']                          35
# Bygel-bh,REA,Bh,Bygel-bh                           ['223,110,27,223']                       76
# Bygel-bh,REA,Bh,Underkläder,Bygel-bh               ['223,110,27,19,223']                    26
# Bygel-bh,Underkläder,Bygel-bh                      ['223,19,223']                           40
# Byxor                                              ['689']                                  387
# Byxor,Byxor                                        ['689,689']                              22
# Byxor,Byxor,Byxor                                  ['689,689,689']                          1
# Byxor,Byxor,Byxor,Nederdelar,Nederdelar,Nederdelar ['689,689,689,1472,1472,1472']           11
# Byxor,Byxor,Capribyxor,Capribyxor,Nederdelar,Nederdelar ['689,689,2094,2094,1472,1472']          44
# Byxor,Byxor,Mjukisbyxor,Mjukisbyxor,Nederdelar,Nederdelar,Mysplagg,Mysplagg ['689,689,2110,2110,1472,1472,1649,1649'] 99
# Byxor,Byxor,Nederdelar,Nederdelar                  ['689,689,1472,1472']                    300
# Byxor,Byxor,Nederdelar,Nederdelar,Jeans,Jeans      ['689,689,1472,1472,2112,2112']          110
# Byxor,Byxor,Nederdelar,Nederdelar,Leggings,Leggings ['689,689,1472,1472,2128,2128']          14
# Byxor,Fritidsbyxor,Fritidskläder,Dam               ['689,2117,1667,471']                    6
# Byxor,Mjukisbyxor,Nederdelar                       ['689,2110,1472']                        9
# Byxor,Nederdelar                                   ['689,1472']                             56
# Byxor,Nederdelar,Dam                               ['689,1472,471']                         15
# Byxor,Nederdelar,Dam,Mysplagg                      ['689,1472,471,1649']                    5
# Byxor,Nederdelar,Jeans                             ['689,1472,2112']                        11
# Byxor,Nederdelar,Leggings                          ['689,1472,2128']                        5
# Byxor,Shorts,Nederdelar                            ['689,1801,1472']                        5
# Bädd                                               ['371']                                  2
# Bädd (linea),Bäddtillbehör                         ['612,827']                              6
# Bädd (linea),Påslakanset                           ['612,165']                              19
# Bädd,Bädd,Bäddtillbehör,Bäddtillbehör,Bädd (linea),Bädd (linea) ['371,371,827,827,612,612']              5
# Bädd,Bädd,Dynor & säten,Dynor & säten,Vardagshjälpmedel,Vardagshjälpmedel ['371,371,2411,2411,497,497']            1
# Bädd,Bädd,Inkontinens,Inkontinens                  ['371,371,1145,1145']                    3
# Bädd,Bädd,Lakan & örngott,Lakan & örngott,Bädd (linea),Bädd (linea) ['371,371,190,190,612,612']              25
# Bädd,Bädd,Stödartiklar,Stödartiklar                ['371,371,1460,1460']                    1
# Bädd,Bädd,Vardagshjälpmedel,Vardagshjälpmedel      ['371,371,497,497']                      2
# Bädd,Bädd,Vardagshjälpmedel,Vardagshjälpmedel,Stödartiklar,Stödartiklar,Bädd (linea),Bädd (linea) ['371,371,497,497,1460,1460,612,612']    1
# Bädd,Bädd,Värmeprodukter,Värmeprodukter            ['371,371,2369,2369']                    2
# Bädd,Bäddtillbehör,Bädd (linea)                    ['371,827,612']                          1
# Bädd,Bäddtillbehör,Lakan & örngott,Bädd (linea)    ['371,827,190,612']                      2
# Bädd,Dynor & säten,Vardagshjälpmedel               ['371,2411,497']                         1
# Bädd,Inkontinens                                   ['371,1145']                             1
# Bädd,REA,Vardagshjälpmedel                         ['371,110,497']                          1
# Bädd,Vardagshjälpmedel                             ['371,497']                              1
# Bädd,Vardagshjälpmedel,Stödartiklar                ['371,497,1460']                         1
# Bädd,Värmeprodukter                                ['371,2369']                             2
# Bäddtillbehör                                      ['827']                                  1
# Bäddtillbehör,Bädd (linea)                         ['827,612']                              6
# Bäddtillbehör,Bädd,Värmeprodukter                  ['827,371,2369']                         2
# Bäddtillbehör,Bäddtillbehör,Bädd (linea),Bädd (linea) ['827,827,612,612']                      2
# Bäddtillbehör,Bäddtillbehör,Bädd,Bädd,Bädd (linea),Bädd (linea) ['827,827,371,371,612,612']              3
# Bäddtillbehör,Bäddtillbehör,Bädd,Bädd,Hälsa,Hälsa,Bädd (linea),Bädd (linea) ['827,827,371,371,1370,1370,612,612']    1
# Bäddtillbehör,Bäddtillbehör,Bädd,Bädd,Inkontinens,Inkontinens,Bädd (linea),Bädd (linea) ['827,827,371,371,1145,1145,612,612']    4
# Bäddtillbehör,Bäddtillbehör,Bädd,Bädd,Värmeprodukter,Värmeprodukter ['827,827,371,371,2369,2369']            2
# Bäddtillbehör,Bäddtillbehör,Bäddtillbehör,Påslakanset,Påslakanset,Påslakanset,REA,REA,REA,Bädd,Bädd,Bädd,Inkontinens,Inkontinens,Inkontinens ['827,827,827,165,165,165,110,110,110,371,371,371,1145,1145,1145'] 1
# Bäddtillbehör,Bäddtillbehör,Dynor & säten,Dynor & säten ['827,827,2411,2411']                    1
# Bäddtillbehör,Bäddtillbehör,Lakan & örngott,Lakan & örngott,Bädd (linea),Bädd (linea) ['827,827,190,190,612,612']              15
# Bäddtillbehör,Bäddtillbehör,Lakan & örngott,Lakan & örngott,Bädd,Bädd,Inkontinens,Inkontinens ['827,827,190,190,371,371,1145,1145']    1
# Bäddtillbehör,Bäddtillbehör,Lakan & örngott,Lakan & örngott,Bädd,Bädd,Inkontinens,Inkontinens,Bädd (linea),Bädd (linea) ['827,827,190,190,371,371,1145,1145,612,612'] 7
# Böcker & häften                                    ['128']                                  7
# Böcker & häften,Böcker & häften                    ['128,128']                              1
# Böcker & häften,Böcker & häften,Böcker & häften    ['128,128,128']                          1
# Capribyxor,Capribyxor,Nederdelar,Nederdelar        ['2094,2094,1472,1472']                  44
# Capribyxor,Capribyxor,Nederdelar,Nederdelar,Byxor,Byxor ['2094,2094,1472,1472,689,689']          33
# Capribyxor,Nederdelar,Byxor                        ['2094,1472,689']                        6
# Dam                                                ['471']                                  9
# Dam,Accessoarer,Kepsar & mössor                    ['471,454,1447']                         12
# Dam,Baddräkter,Badkläder,Kjolbaddräkter            ['471,469,470,2354']                     12
# Dam,Badkläder,Tankini                              ['471,470,1835']                         14
# Dam,Bh utan kupstorlek,Bikini,Badkläder,Bh utan kupstorlek ['471,41,736,470,41']                    14
# Dam,Bikini,Badkläder                               ['471,736,470']                          77
# Dam,Dam,Byxor,Byxor,Nederdelar,Nederdelar          ['471,471,689,689,1472,1472']            42
# Dam,Dam,Dam,Byxor,Byxor,Byxor,Nederdelar,Nederdelar,Nederdelar ['471,471,471,689,689,689,1472,1472,1472'] 2
# Dam,Dam,Skor,Skor,Skor & tofflor,Skor & tofflor    ['471,471,1426,1426,1449,1449']          10
# Dam,Jackor,Ytterplagg                              ['471,2228,2229']                        6
# Dam,REA,Toppar,Överdelar                           ['471,110,48,1552']                      24
# Dam,Skor,Skor & tofflor                            ['471,1426,1449']                        5
# Dekorationer,Dekorationer,Dekorationer             ['166,166,166']                          4
# Dekorationer,Dekorationer,Dekorationer,Halsdukar & sjalar,Halsdukar & sjalar,Halsdukar & sjalar ['166,166,166,7,7,7']                    1
# Dekorationer,Dekorationer,Dekorationer,Juldekoration,Juldekoration,Juldekoration ['166,166,166,213,213,213']              3
# Dekorationer,Dekorationer,Dekorationer,Juldekoration,Juldekoration,Juldekoration,REA,REA,REA ['166,166,166,213,213,213,110,110,110']  1
# Dekorationer,Dekorationer,Dekorationer,Prydnadssaker,Prydnadssaker,Prydnadssaker ['166,166,166,208,208,208']              13
# Dekorationer,Dekorationer,Dekorationer,Prydnadssaker,Prydnadssaker,Prydnadssaker,REA,REA,REA ['166,166,166,208,208,208,110,110,110']  6
# Dekorationer,Dekorationer,Dekorationer,REA,REA,REA ['166,166,166,110,110,110']              1
# Dekorationer,Dekorationer,Juldekoration,Juldekoration ['166,166,213,213']                      1
# Dekorationer,Dekorationer,Prydnadssaker,Prydnadssaker,REA,REA ['166,166,208,208,110,110']              1
# Dekorationer,Halsdukar & sjalar                    ['166,7']                                1
# Dekorationer,Prydnadssaker                         ['166,208']                              2
# Dekorationsbelysning,Dekorationsbelysning,Dekorationsbelysning ['672,672,672']                          4
# Doftpåsar,Lust,Hälsa                               ['355,2396,1370']                        6
# Dukar                                              ['144']                                  9
# Dukar,Dukar                                        ['144,144']                              32
# Dukar,Dukar,Dukar                                  ['144,144,144']                          17
# Dukar,Dukar,Dukar,Kökshjälpmedel,Kökshjälpmedel,Kökshjälpmedel,REA,REA,REA ['144,144,144,1418,1418,1418,110,110,110'] 1
# Dukar,Dukar,Dukar,Plädar,Plädar,Plädar,REA,REA,REA ['144,144,144,265,265,265,110,110,110']  1
# Dukar,Dukar,Dukar,REA,REA,REA                      ['144,144,144,110,110,110']              4
# Dukar,Dukar,Dukar,REA,REA,REA,REA,REA,REA          ['144,144,144,110,110,110,110,110,110']  1
# Dukar,Dukar,Dukar,Vaxdukar,Vaxdukar,Vaxdukar       ['144,144,144,852,852,852']              6
# Dukar,Dukar,Vaxdukar,Vaxdukar                      ['144,144,852,852']                      20
# Dukar,Dukar,Vaxdukar,Vaxdukar,Dukar,Dukar,Vaxdukar,Vaxdukar ['144,144,852,852,144,144,852,852']      2
# Dukar,Kökshjälpmedel,REA                           ['144,1418,110']                         1
# Dukar,Plädar,REA                                   ['144,265,110']                          1
# Dukar,REA                                          ['144,110']                              3
# Dukar,Vaxdukar                                     ['144,852']                              2
# Duschdraperier,Duschdraperier                      ['338,338']                              1
# Duschdraperier,Duschdraperier,Bad,Bad              ['338,338,646,646']                      12
# Duschdraperier,Duschdraperier,Badrum/WC,Badrum/WC  ['338,338,481,481']                      3
# Duschdraperier,Duschdraperier,Badrum/WC,Badrum/WC,Bad,Bad ['338,338,481,481,646,646']              1
# Duschdraperier,Duschdraperier,REA,REA,Badrum/WC,Badrum/WC ['338,338,110,110,481,481']              2
# Duschdraperier,REA,Kroppsvård                      ['338,110,1079']                         5
# Dynor & säten,Dynor & säten                        ['2411,2411']                            1
# Dörr- & trappstegsmattor,Dörr- & trappstegsmattor,Dörr- & trappstegsmattor ['433,433,433']                          4
# Dörr- & trappstegsmattor,Dörr- & trappstegsmattor,Dörr- & trappstegsmattor,Juldekoration,Juldekoration,Juldekoration ['433,433,433,213,213,213']              1
# Fleecejackor,Fleecejackor,Fritidskläder,Fritidskläder,Ytterplagg,Ytterplagg ['2231,2231,1667,1667,2229,2229']        6
# Fleecejackor,Fritidskläder,Dam                     ['2231,1667,471']                        6
# Fleecejackor,Överdelar,Dam                         ['2231,1552,471']                        6
# Fleecejackor,Överdelar,Fritidskläder,Dam           ['2231,1552,1667,471']                   6
# Flexitavlor,Flexitavlor,Flexitavlor,Broderikit,Broderikit,Broderikit ['155,155,155,3953,3953,3953']           1
# Fotvård                                            ['1981']                                 38
# Fotvård,Fotvård                                    ['1981,1981']                            11
# Fotvård,Fotvård,Badrum/WC,Badrum/WC,Vardagshjälpmedel,Vardagshjälpmedel ['1981,1981,481,481,497,497']            1
# Fotvård,Fotvård,Fotvård,Handvård,Handvård,Handvård,Badrum/WC,Badrum/WC,Badrum/WC,Vardagshjälpmedel,Vardagshjälpmedel,Vardagshjälpmedel ['1981,1981,1981,1639,1639,1639,481,481,481,497,497,497'] 1
# Fotvård,Fotvård,Fotvård,Handvård,Handvård,Handvård,REA,REA,REA ['1981,1981,1981,1639,1639,1639,110,110,110'] 1
# Fotvård,Fotvård,Fotvård,Massage,Massage,Massage,Hälsa,Hälsa,Hälsa ['1981,1981,1981,1369,1369,1369,1370,1370,1370'] 1
# Fotvård,Fotvård,Fotvård,Stödartiklar,Stödartiklar,Stödartiklar ['1981,1981,1981,1460,1460,1460']        1
# Fotvård,Fotvård,Massage,Massage,Värmeprodukter,Värmeprodukter ['1981,1981,1369,1369,2369,2369']        1
# Fotvård,Fotvård,Stödartiklar,Stödartiklar          ['1981,1981,1460,1460']                  9
# Fotvård,Fotvård,Vardagshjälpmedel,Vardagshjälpmedel ['1981,1981,497,497']                    1
# Fotvård,Halkskydd                                  ['1981,545']                             2
# Fotvård,Handvård                                   ['1981,1639']                            15
# Fotvård,Handvård,Kroppsvård                        ['1981,1639,1079']                       3
# Fotvård,Handvård,REA                               ['1981,1639,110']                        3
# Fotvård,Handvård,REA,Kroppsvård                    ['1981,1639,110,1079']                   1
# Fotvård,Handvård,REA,Vardagshjälpmedel             ['1981,1639,110,497']                    1
# Fotvård,Kroppsvård                                 ['1981,1079']                            5
# Fotvård,Massage                                    ['1981,1369']                            1
# Fotvård,Massage,Kroppsvård,Handvård                ['1981,1369,1079,1639']                  1
# Fotvård,Massage,REA                                ['1981,1369,110']                        1
# Fotvård,REA                                        ['1981,110']                             7
# Fotvård,Stödartiklar                               ['1981,1460']                            3
# Fotvård,Värmeprodukter                             ['1981,2369']                            1
# Framknäppt bh,Bh,Framknäppt bh                     ['189,27,189']                           54
# Framknäppt bh,Bh,Korsetter,Framknäppt bh           ['189,27,934,189']                       36
# Framknäppt bh,Bh,Underkläder,Framknäppt bh         ['189,27,19,189']                        59
# Framknäppt bh,Framknäppt bh,Bh,Bh,Underkläder,Underkläder ['189,189,27,27,19,19']                  5
# Framknäppt bh,Framknäppt bh,Bh,Bh,Underkläder,Underkläder,Framknäppt bh,Framknäppt bh ['189,189,27,27,19,19,189,189']          22
# Fritidsbyxor,Fritidskläder                         ['2117,1667']                            124
# Fritidsbyxor,Fritidskläder,Dam                     ['2117,1667,471']                        6
# Fritidsbyxor,Fritidskläder,Dam,Herr                ['2117,1667,471,162']                    5
# Fritidsbyxor,Fritidskläder,Nederdelar              ['2117,1667,1472']                       5
# Fritidsjackor,Fritidsjackor,Överdelar,Överdelar,Fritidskläder,Fritidskläder,Dam,Dam,Jackor,Jackor ['2233,2233,1552,1552,1667,1667,471,471,2228,2228'] 5
# Fritidsjackor,Fritidskläder                        ['2233,1667']                            37
# Fritidsjackor,REA,Fleecejackor,Överdelar,Fritidskläder,Ytterplagg ['2233,110,2231,1552,1667,2229']         60
# Fritidsjackor,Överdelar,Fritidskläder              ['2233,1552,1667']                       12
# Fritidskläder,Fritidsset                           ['1667,2368']                            5
# Fritidskläder,Underställ                           ['1667,2377']                            4
# Fritidskläder,Underställ,Nederdelar,Överdelar,Långkalsonger ['1667,2377,1472,1552,44']               4
# Fritidsplagg                                       ['3687']                                 9
# Fritidsplagg,Mysplagg                              ['3687,1649']                            5
# Frottéhanddukar & badlakan                         ['262']                                  38
# Frottéhanddukar & badlakan,Frottéhanddukar & badlakan ['262,262']                              18
# Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,Bad,Bad ['262,262,646,646']                      160
# Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,Bad,Bad,Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,Bad,Bad,Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,Bad,Bad ['262,262,646,646,262,262,646,646,262,262,646,646'] 8
# Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,Frottéhanddukar & badlakan ['262,262,262']                          48
# Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,REA,REA,REA ['262,262,262,110,110,110']              6
# Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,REA,REA,REA,REA,REA,REA ['262,262,262,110,110,110,110,110,110']  2
# Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,Kroppsvård,Kroppsvård,Badrum/WC,Badrum/WC,Barnrummet,Barnrummet,Bad,Bad ['262,262,1079,1079,481,481,195,195,646,646'] 7
# Frottéhanddukar & badlakan,Frottéhanddukar & badlakan,REA,REA ['262,262,110,110']                      1
# Frottéhanddukar & badlakan,REA                     ['262,110']                              5
# Frottéhanddukar & badlakan,REA,Picknick och uteliv ['262,110,417']                          1
# Fönsterlampor                                      ['215']                                  1
# Fönsterlampor,Fönsterlampor,Fönsterlampor,Dekorationsbelysning,Dekorationsbelysning,Dekorationsbelysning ['215,215,215,672,672,672']              1
# Gardinbåge,Gardinbåge                              ['1031,1031']                            13
# Gardinkappor                                       ['118']                                  12
# Gardinkappor,Kanallängder                          ['118,175']                              2
# Gardinkappor,REA                                   ['118,110']                              8
# Gardinset                                          ['951']                                  3
# Gardinstänger                                      ['282']                                  3
# Gardinstänger,Gardinstänger,Gardinstänger          ['282,282,282']                          7
# Gardinstänger,Gardinstänger,Gardinstänger,REA,REA,REA ['282,282,282,110,110,110']              1
# Gardinstänger,REA                                  ['282,110']                              6
# Glas & porslin,Glas & porslin                      ['486,486']                              1
# Glas & porslin,Glas & porslin,Glas & porslin       ['486,486,486']                          2
# Gånghjälpmedel                                     ['2395']                                 3
# Gånghjälpmedel,Gånghjälpmedel                      ['2395,2395']                            10
# Gånghjälpmedel,Rollatorer                          ['2395,2069']                            11
# Halkskydd                                          ['545']                                  34
# Halkskydd,Gånghjälpmedel                           ['545,2395']                             2
# Halkskydd,Halkskydd,Gånghjälpmedel,Gånghjälpmedel  ['545,545,2395,2395']                    1
# Halkskydd,Halkskydd,Strumpor,Strumpor,Underkläder,Underkläder,Halksockor,Halksockor ['545,545,95,95,19,19,1526,1526']        4
# Halkskydd,REA                                      ['545,110']                              14
# Halsdukar & sjalar                                 ['7']                                    21
# Halsdukar & sjalar,Halsdukar & sjalar              ['7,7']                                  1
# Halsdukar & sjalar,Halsdukar & sjalar,Halsdukar & sjalar ['7,7,7']                                9
# Handdukar,Handdukar                                ['224,224']                              6
# Handdukar,Handdukar,Handdukar                      ['224,224,224']                          1
# Handdukar,Handdukar,Handdukar,Kökshanddukar,Kökshanddukar,Kökshanddukar,REA,REA,REA ['224,224,224,276,276,276,110,110,110']  1
# Handskar & vantar                                  ['1415']                                 12
# Handskar & vantar,Accessoarer                      ['1415,454']                             9
# Handskar & vantar,Dam,Accessoarer                  ['1415,471,454']                         8
# Handskar & vantar,Handskar & vantar,Accessoarer,Accessoarer ['1415,1415,454,454']                    4
# Handskar & vantar,Handskar & vantar,Dam,Dam,Accessoarer,Accessoarer ['1415,1415,471,471,454,454']            2
# Handskar & vantar,Handskar & vantar,Handskar & vantar ['1415,1415,1415']                       2
# Handvård                                           ['1639']                                 4
# Handvård,Handvård,Stödartiklar,Stödartiklar        ['1639,1639,1460,1460']                  1
# Handvård,REA                                       ['1639,110']                             1
# Hattar                                             ['1420']                                 16
# Hattar,Accessoarer                                 ['1420,454']                             4
# Hattar,Hattar                                      ['1420,1420']                            8
# Hattar,Sjalar & halsdukar                          ['1420,854']                             1
# Heminredning                                       ['10']                                   1
# Herr                                               ['162']                                  1
# Herr,Byxor                                         ['162,689']                              4
# Herr,Fleecejackor                                  ['162,2231']                             8
# Herr,Fritidsbyxor,Fritidskläder                    ['162,2117,1667']                        20
# Herr,Långkalsonger,Underkläder                     ['162,44,19']                            6
# Herr,Pyjamas,Sovkläder                             ['162,2132,1451']                        6
# Herr,Sovkläder,Nattskjortor                        ['162,1451,2381']                        16
# Herr,Tofflor                                       ['162,667']                              14
# Herr,Tofflor,Dam,Skor                              ['162,667,471,1426']                     13
# Herr,Överdelar,T-shirts                            ['162,1552,1663']                        63
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Diamond painting,Diamond painting,Diamond painting ['172,172,172,173,173,173']              1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Juldekoration,Juldekoration,Juldekoration,Pussel,Pussel,Pussel,Sällskapsspel,Sällskapsspel,Sällskapsspel ['172,172,172,213,213,213,365,365,365,436,436,436'] 3
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel 1000 bitar,Pussel 1000 bitar,Pussel 1000 bitar ['172,172,172,485,485,485']              7
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel 1000 bitar,Pussel 1000 bitar,Pussel 1000 bitar,Pussel,Pussel,Pussel ['172,172,172,485,485,485,365,365,365']  1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel 1000 bitar,Pussel 1000 bitar,Pussel 1000 bitar,REA,REA,REA ['172,172,172,485,485,485,110,110,110']  2
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel 2000 bitar,Pussel 2000 bitar,Pussel 2000 bitar,Pussel,Pussel,Pussel ['172,172,172,1351,1351,1351,365,365,365'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel 275 bitar,Pussel 275 bitar,Pussel 275 bitar,REA,REA,REA ['172,172,172,804,804,804,110,110,110']  1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel 500 bitar,Pussel 500 bitar,Pussel 500 bitar,REA,REA,REA ['172,172,172,499,499,499,110,110,110']  1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel ['172,172,172,365,365,365']              31
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 100 bitar,Pussel 100 bitar,Pussel 100 bitar ['172,172,172,365,365,365,2461,2461,2461'] 3
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 1000 bitar,Pussel 1000 bitar,Pussel 1000 bitar ['172,172,172,365,365,365,485,485,485']  134
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 1000 bitar,Pussel 1000 bitar,Pussel 1000 bitar,REA,REA,REA ['172,172,172,365,365,365,485,485,485,110,110,110'] 20
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 13 200 Bitar,Pussel 13 200 Bitar,Pussel 13 200 Bitar ['172,172,172,365,365,365,1284,1284,1284'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 1500 bitar,Pussel 1500 bitar,Pussel 1500 bitar ['172,172,172,365,365,365,546,546,546']  6
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 1500 bitar,Pussel 1500 bitar,Pussel 1500 bitar,REA,REA,REA ['172,172,172,365,365,365,546,546,546,110,110,110'] 4
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 20 Bitar,Pussel 20 Bitar,Pussel 20 Bitar ['172,172,172,365,365,365,1282,1282,1282'] 2
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 200 bitar,Pussel 200 bitar,Pussel 200 bitar ['172,172,172,365,365,365,2462,2462,2462'] 3
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 200 bitar,Pussel 200 bitar,Pussel 200 bitar,REA,REA,REA ['172,172,172,365,365,365,2462,2462,2462,110,110,110'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 2000 bitar,Pussel 2000 bitar,Pussel 2000 bitar ['172,172,172,365,365,365,1351,1351,1351'] 5
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 2000 bitar,Pussel 2000 bitar,Pussel 2000 bitar,REA,REA,REA ['172,172,172,365,365,365,1351,1351,1351,110,110,110'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 275 bitar,Pussel 275 bitar,Pussel 275 bitar ['172,172,172,365,365,365,804,804,804']  2
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 300 bitar,Pussel 300 bitar,Pussel 300 bitar ['172,172,172,365,365,365,2440,2440,2440'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 300 bitar,Pussel 300 bitar,Pussel 300 bitar,REA,REA,REA ['172,172,172,365,365,365,2440,2440,2440,110,110,110'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 3000 Bitar,Pussel 3000 Bitar,Pussel 3000 Bitar ['172,172,172,365,365,365,1281,1281,1281'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 32 bitar,Pussel 32 bitar,Pussel 32 bitar ['172,172,172,365,365,365,1961,1961,1961'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 350 bitar,Pussel 350 bitar,Pussel 350 bitar ['172,172,172,365,365,365,800,800,800']  9
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 500 bitar,Pussel 500 bitar,Pussel 500 bitar ['172,172,172,365,365,365,499,499,499']  44
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 500 bitar,Pussel 500 bitar,Pussel 500 bitar,Pussel 1000 bitar,Pussel 1000 bitar,Pussel 1000 bitar ['172,172,172,365,365,365,499,499,499,485,485,485'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,Pussel 500 bitar,Pussel 500 bitar,Pussel 500 bitar,REA,REA,REA ['172,172,172,365,365,365,499,499,499,110,110,110'] 16
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pussel,Pussel,Pussel,REA,REA,REA ['172,172,172,365,365,365,110,110,110']  2
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,Pysselset,Pysselset,Pysselset ['172,172,172,241,241,241']              2
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,REA,REA,REA,Pussel,Pussel,Pussel ['172,172,172,110,110,110,365,365,365']  1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,REA,REA,REA,Pussel,Pussel,Pussel,Pussel 1000 bitar,Pussel 1000 bitar,Pussel 1000 bitar ['172,172,172,110,110,110,365,365,365,485,485,485'] 3
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,REA,REA,REA,Pussel,Pussel,Pussel,Pussel 32 bitar,Pussel 32 bitar,Pussel 32 bitar ['172,172,172,110,110,110,365,365,365,1961,1961,1961'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,REA,REA,REA,Pussel,Pussel,Pussel,Pussel 32 bitar,Pussel 32 bitar,Pussel 32 bitar,REA,REA,REA ['172,172,172,110,110,110,365,365,365,1961,1961,1961,110,110,110'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,REA,REA,REA,Pussel,Pussel,Pussel,Pussel 4000 bitar,Pussel 4000 bitar,Pussel 4000 bitar ['172,172,172,110,110,110,365,365,365,2455,2455,2455'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,REA,REA,REA,Pussel,Pussel,Pussel,Pussel 500 bitar,Pussel 500 bitar,Pussel 500 bitar ['172,172,172,110,110,110,365,365,365,499,499,499'] 1
# Hobbyhörnan,Hobbyhörnan,Hobbyhörnan,REA,REA,REA,Pussel,Pussel,Pussel,Pussel 500 bitar,Pussel 500 bitar,Pussel 500 bitar,REA,REA,REA ['172,172,172,110,110,110,365,365,365,499,499,499,110,110,110'] 1
# ...
# Tvätt & skötsel,Tvätt & skötsel,Tvätt & skötsel,Sytillbehör,Sytillbehör,Sytillbehör,Vardagshjälpmedel,Vardagshjälpmedel,Vardagshjälpmedel ['926,926,926,151,151,151,497,497,497']  1
# Tvätt & skötsel,Tvätt & skötsel,Tvätt & skötsel,Vardagshjälpmedel,Vardagshjälpmedel,Vardagshjälpmedel ['926,926,926,497,497,497']              3
# Tvätt & skötsel,Tvätt & skötsel,Tvätt & skötsel,Vardagshjälpmedel,Vardagshjälpmedel,Vardagshjälpmedel,Hushåll övrigt,Hushåll övrigt,Hushåll övrigt ['926,926,926,497,497,497,392,392,392']  1
# Tvätt & skötsel,Tvätt & skötsel,Tvätt & skötsel,Vardagshjälpmedel,Vardagshjälpmedel,Vardagshjälpmedel,Symaskiner och tillbehör,Symaskiner och tillbehör,Symaskiner och tillbehör,Hushåll övrigt,Hushåll övrigt,Hushåll övrigt ['926,926,926,497,497,497,228,228,228,392,392,392'] 1
# Täcken                                             ['826']                                  1
# Täcken,Täcken,Bädd (linea),Bädd (linea)            ['826,826,612,612']                      13
# Täcken,Täcken,Bädd,Bädd,REA,REA                    ['826,826,371,371,110,110']              4
# Täcken,Täcken,Bäddtillbehör,Bäddtillbehör,Bädd (linea),Bädd (linea) ['826,826,827,827,612,612']              1
# Täcken,Täcken,Bäddtillbehör,Bäddtillbehör,Bädd (linea),Bädd (linea),Kuddar,Kuddar,Innerkuddar,Innerkuddar ['826,826,827,827,612,612,186,186,517,517'] 1
# Täcken,Täcken,Täcken                               ['826,826,826']                          1
# Underkjolar                                        ['1275']                                 14
# Underkjolar,Underkjolar,Underkjolar,Underkläder,Underkläder,Underkläder ['1275,1275,1275,19,19,19']              1
# Underkjolar,Underkläder                            ['1275,19']                              116
# Underkjolar,Underkläder,Underkjolar,Underkläder    ['1275,19,1275,19']                      1
# Underkläder,Accessoarer,Bh-tillbehör               ['19,454,691']                           1
# Underkläder,Bh                                     ['19,27']                                84
# Underkläder,Bh utan bygel                          ['19,50']                                90
# Underkläder,Bh utan bygel,Bh                       ['19,50,27']                             479
# Underkläder,Bh utan bygel,Bh,Bh utan bygel         ['19,50,27,50']                          576
# Underkläder,Bh utan bygel,Bh,Bh utan bygel,Linnen  ['19,50,27,50,154']                      105
# Underkläder,Bh utan bygel,Bh,Underkläder,Bh utan bygel,Bh,Underkläder,Bh utan bygel,Bh,Sport-bh ['19,50,27,19,50,27,19,50,27,618']       62
# Underkläder,Bh utan bygel,Body                     ['19,50,450']                            18
# Underkläder,Bh utan bygel,Body,Bh utan bygel       ['19,50,450,50']                         168
# Underkläder,Bh utan bygel,Sport-bh                 ['19,50,618']                            12
# Underkläder,Bh,Bh utan bygel                       ['19,27,50']                             115
# Underkläder,Bh,Bygel-bh                            ['19,27,223']                            308
# Underkläder,Bh,Framknäppt bh,Bh utan bygel         ['19,27,189,50']                         56
# Underkläder,Bh,Minimizer                           ['19,27,808']                            52
# Underkläder,Bh,Sport-bh                            ['19,27,618']                            86
# Underkläder,Bygel-bh                               ['19,223']                               55
# Underkläder,Bygel-bh,Bh                            ['19,223,27']                            606
# Underkläder,Bygel-bh,Bh,Underkläder,Bygel-bh,Bh    ['19,223,27,19,223,27']                  28
# Underkläder,Bygel-bh,Sport-bh                      ['19,223,618']                           70
# Underkläder,Dam,Trosor                             ['19,471,20']                            50
# Underkläder,Gördlar                                ['19,1797']                              342
# Underkläder,Gördlar,Underkläder,Gördlar,Underkläder,Gördlar ['19,1797,19,1797,19,1797']              3
# Underkläder,Gördlar,Underkläder,Gördlar,Underkläder,Gördlar,Underkläder,Gördlar ['19,1797,19,1797,19,1797,19,1797']      8
# Underkläder,Linnen                                 ['19,154']                               10
# Underkläder,Linnen,Bh                              ['19,154,27']                            36
# Underkläder,Nattlinnen                             ['19,1450']                              2
# Underkläder,Sport-bh,Bh utan bygel,Bh              ['19,618,50,27']                         41
# Underkläder,Sport-bh,Bh utan bygel,Bh,Sport-bh,Bh utan bygel ['19,618,50,27,618,50']                  504
# Underkläder,Sport-bh,Bh utan bygel,Bh,Underkläder,Sport-bh,Bh utan bygel,Bh ['19,618,50,27,19,618,50,27']            25
# Underkläder,Sport-bh,Bh utan bygel,Bh,Underkläder,Sport-bh,Bh utan bygel,Bh,Underkläder,Sport-bh,Bh utan bygel,Bh ['19,618,50,27,19,618,50,27,19,618,50,27'] 4
# Underkläder,Sport-bh,Bh,Sport-bh                   ['19,618,27,618']                        91
# Underkläder,Strumpor                               ['19,95']                                12
# Underkläder,Strumpor,Herr,Bh utan bygel,Bh,Bh utan bygel ['19,95,162,50,27,50']                   40
# Underkläder,Stödstrumpor                           ['19,639']                               6
# Underkläder,Trosor                                 ['19,20']                                1789
# Underkläder,Trosor & gördlar                       ['19,2364']                              10
# Underkläder,Trosor & gördlar,Trosor                ['19,2364,20']                           24
# Underkläder,Trosor,Gördlar                         ['19,20,1797']                           107
# Underkläder,Trosor,Mamelucker                      ['19,20,2325']                           41
# Underkläder,Trosor,Underkläder,Trosor              ['19,20,19,20']                          37
# Underkläder,Trosor,Underkläder,Trosor,Mamelucker   ['19,20,19,20,2325']                     3
# Underkläder,Trosor,Underkläder,Trosor,Underkläder,Trosor ['19,20,19,20,19,20']                    2
# Underkläder,Trosor,Underkläder,Trosor,Underkläder,Trosor,Underkläder,Trosor ['19,20,19,20,19,20,19,20']              5
# Underkläder,Trosor,Underkläder,Trosor,Underkläder,Trosor,Underkläder,Trosor,Underkläder,Trosor ['19,20,19,20,19,20,19,20,19,20']        5
# Underkläder,Underkläder,Bh utan bygel,Bh utan bygel,Bh,Bh ['19,19,50,50,27,27']                    1
# Underkläder,Underkläder,Bygel-bh,Bygel-bh,Bh,Bh    ['19,19,223,223,27,27']                  44
# Underkläder,Underkläder,Bygel-bh,Bygel-bh,Bh,Bh,Bygel-bh,Bygel-bh ['19,19,223,223,27,27,223,223']          84
# Underkläder,Underkläder,Gördlar,Gördlar            ['19,19,1797,1797']                      7
# Underkläder,Underkläder,Kalsonger,Kalsonger        ['19,19,92,92']                          9
# Underkläder,Underkläder,Linnen,Linnen              ['19,19,154,154']                        21
# Underkläder,Underkläder,Mamelucker,Mamelucker      ['19,19,2325,2325']                      6
# Underkläder,Underkläder,Mamelucker,Mamelucker,Trosor,Trosor ['19,19,2325,2325,20,20']                10
# Underkläder,Underkläder,Trosor,Trosor              ['19,19,20,20']                          662
# Underkläder,Underkläder,Trosor,Trosor,Byxor,Byxor  ['19,19,20,20,689,689']                  22
# Underkläder,Underkläder,Trosor,Trosor,Gördlar,Gördlar ['19,19,20,20,1797,1797']                32
# Underkläder,Underkläder,Trosor,Trosor,Mamelucker,Mamelucker ['19,19,20,20,2325,2325']                9
# Underkläder,Underkläder,Underkläder,Gördlar,Gördlar,Gördlar ['19,19,19,1797,1797,1797']              13
# Underkläder,Underkläder,Underkläder,Trosor,Trosor,Trosor ['19,19,19,20,20,20']                    133
# Underkläder,Underkläder,Underkläder,Trosor,Trosor,Trosor,Mamelucker,Mamelucker,Mamelucker ['19,19,19,20,20,20,2325,2325,2325']     57
# Underkläder,Underkläder,Underkläder,Underklänningar,Underklänningar,Underklänningar ['19,19,19,1272,1272,1272']              1
# Underkläder,Underkläder,Underkläder,Undertröjor,Undertröjor,Undertröjor ['19,19,19,2298,2298,2298']              8
# Underkläder,Underkläder,Undertröjor,Undertröjor    ['19,19,2298,2298']                      12
# Underkläder,Underklänningar                        ['19,1272']                              67
# Underkläder,Undertröjor                            ['19,2298']                              24
# Vantar                                             ['45']                                   1
# Vantar,Vantar                                      ['45,45']                                1
# Vardagshjälpmedel                                  ['497']                                  46
# Vardagshjälpmedel,Vardagshjälpmedel                ['497,497']                              5
# Vardagshjälpmedel,Vardagshjälpmedel,Dynor & säten,Dynor & säten ['497,497,2411,2411']                    4
# Vardagshjälpmedel,Vardagshjälpmedel,Strumpor,Strumpor ['497,497,95,95']                        1
# Vardagshjälpmedel,Vardagshjälpmedel,Synhjälpmedel,Synhjälpmedel,Belysning,Belysning ['497,497,217,217,460,460']              1
# Vardagshjälpmedel,Vardagshjälpmedel,Vardagshjälpmedel ['497,497,497']                          5
# Vaxdukar,Vaxdukar                                  ['852,852']                              18
# Vaxdukar,Vaxdukar,Dukar,Dukar                      ['852,852,144,144']                      60
# Vaxdukar,Vaxdukar,Vaxdukar                         ['852,852,852']                          7
# Vaxdukar,Vaxdukar,Vaxdukar,Dukar,Dukar,Dukar       ['852,852,852,144,144,144']              4
# Vepor & bonader,Vepor & bonader,Vepor & bonader    ['161,161,161']                          1
# Vepor & bonader,Vepor & bonader,Vepor & bonader,REA,REA,REA,Broderikit,Broderikit,Broderikit ['161,161,161,110,110,110,3953,3953,3953'] 2
# Virknålar,Virknålar,Virknålar,Vardagshjälpmedel,Vardagshjälpmedel,Vardagshjälpmedel ['534,534,534,497,497,497']              13
# Vägglampor,Vägglampor,Vägglampor,REA,REA,REA       ['280,280,280,110,110,110']              1
# Värmeprodukter                                     ['2369']                                 8
# Värmeprodukter,Värmeprodukter,Värmeprodukter       ['2369,2369,2369']                       1
# Väskor                                             ['200']                                  43
# Väskor & fodral,Hushåll övrigt,Hyllor & förvaring  ['199,392,235']                          1
# Väskor & fodral,Väskor & fodral,Väskor & fodral,Väskor,Väskor,Väskor ['199,199,199,200,200,200']              1
# Väskor,Badrumstillbehör                            ['200,339']                              1
# Väskor,Vardagshjälpmedel                           ['200,497']                              1
# Väskor,Väskor                                      ['200,200']                              3
# Väskor,Väskor,Accessoarer,Accessoarer              ['200,200,454,454']                      1
# Väskor,Väskor,Badrumstillbehör,Badrumstillbehör,Bad,Bad ['200,200,339,339,646,646']              2
# Väskor,Väskor,Hushåll övrigt,Hushåll övrigt        ['200,200,392,392']                      2
# Väskor,Väskor,Hushåll övrigt,Hushåll övrigt,Accessoarer,Accessoarer ['200,200,392,392,454,454']              14
# Väskor,Väskor,Väskor                               ['200,200,200']                          8
# Väskor,Väskor,Väskor,Badrumstillbehör,Badrumstillbehör,Badrumstillbehör ['200,200,200,339,339,339']              1
# Västar                                             ['37']                                   58
# Västar,REA,Värmeprodukter                          ['37,110,2369']                          6
# Västar,Västar,Ytterplagg,Ytterplagg                ['37,37,2229,2229']                      9
# Västar,Västar,Överdelar,Överdelar                  ['37,37,1552,1552']                      11
# Västar,Överdelar                                   ['37,1552']                              6
# Västar,Överdelar,Dam                               ['37,1552,471']                          11
# Ytterplagg,Fritidsjackor,Fleecejackor,Fritidskläder ['2229,2233,2231,1667']                  64
# Ytterplagg,Fritidskläder,Mysplagg                  ['2229,1667,1649']                       3
# Ytterplagg,Fritidskläder,Mysplagg,Ytterplagg,Fritidskläder,Mysplagg ['2229,1667,1649,2229,1667,1649']        2
# Ytterplagg,Jackor                                  ['2229,2228']                            36
# Ytterplagg,Ytterplagg,Kappor,Kappor                ['2229,2229,2232,2232']                  9
# Öljettkappa,Öljettkappa                            ['893,893']                              5
# Öljettlängder,Öljettlängder                        ['841,841']                              4
# Överdelar                                          ['1552']                                 18
# Överdelar,Bh-toppar                                ['1552,40']                              9
# Överdelar,Blusar                                   ['1552,1533']                            63
# Överdelar,Dam,Jackor                               ['1552,471,2228']                        6
# Överdelar,Herr,Jackor                              ['1552,162,2228']                        5
# Överdelar,Jackor                                   ['1552,2228']                            10
# Överdelar,Jackor,Ytterplagg                        ['1552,2228,2229']                       6
# Överdelar,Koftor                                   ['1552,14']                              42
# Överdelar,Skjortor                                 ['1552,1519']                            21
# Överdelar,Skjortor,Överdelar,Skjortor              ['1552,1519,1552,1519']                  6
# Överdelar,T-shirts                                 ['1552,1663']                            6
# Överdelar,Toppar                                   ['1552,48']                              65
# Överdelar,Tröjor                                   ['1552,17']                              119
# Överdelar,Tunikor                                  ['1552,451']                             102
# Överdelar,Tunikor,Fritidsset                       ['1552,451,2368']                        5
# Överdelar,Tunikor,Skjortor                         ['1552,451,1519']                        9
# Överdelar,Tunikor,Överdelar,Tunikor                ['1552,451,1552,451']                    8
# Överdelar,Tunikor,Överdelar,Tunikor,Överdelar,Tunikor ['1552,451,1552,451,1552,451']           6
# Överdelar,Tunikor,Överdelar,Tunikor,Överdelar,Tunikor,Överdelar,Tunikor ['1552,451,1552,451,1552,451,1552,451']  5
# Överdelar,Ytterplagg,Fleecejackor,Överdelar,Ytterplagg,Fleecejackor ['1552,2229,2231,1552,2229,2231']        5
# Överdelar,Överdelar,Blusar,Blusar,Skjortor,Skjortor ['1552,1552,1533,1533,1519,1519']        9
# Överdelar,Överdelar,Dam,Dam,Fleecejackor,Fleecejackor ['1552,1552,471,471,2231,2231']          5
# Överdelar,Överdelar,T-shirts,T-shirts              ['1552,1552,1663,1663']                  34
# Överdelar,Överdelar,Toppar,Toppar                  ['1552,1552,48,48']                      10
# Överdelar,Överdelar,Tröjor,Tröjor                  ['1552,1552,17,17']                      116
# Överdelar,Överdelar,Tröjor,Tröjor,Överdelar,Överdelar,Tröjor,Tröjor ['1552,1552,17,17,1552,1552,17,17']      1
# Överdelar,Överdelar,Tunikor,Tunikor                ['1552,1552,451,451']                    10
# Överdelar,Överdelar,Ytterplagg,Ytterplagg,Kappor,Kappor ['1552,1552,2229,2229,2232,2232']        6
# Överdelar,Överdelar,Överdelar,T-shirts,T-shirts,T-shirts ['1552,1552,1552,1663,1663,1663']        6
# Överdelar,Överdelar,Överdelar,Tröjor,Tröjor,Tröjor ['1552,1552,1552,17,17,17']              10
# Överkast                                           ['244']                                  9
# Överkast,REA                                       ['244,110']                              2
# Överkast,Överkast,Överkast                         ['244,244,244']                          1
# Övriga broderier,Övriga broderier,Övriga broderier ['230,230,230']                          1
#
# No category has >1 categoryId.
#
# Articles without categoryId: 5746
# Articles without category: 5746

# %%
# category↔ID mapping

def dedup_csv(s):
    if pd.isna(s): return pd.NA
    out, seen = [], set()
    for t in map(str.strip, str(s).split(',')):
        if t and t not in seen: seen.add(t); out.append(t)
    return ','.join(out) if out else pd.NA

def toks(s):
    return [t.strip() for t in str(s).split(',') if t.strip()] if pd.notna(s) else []

articles['category']   = articles['category'].apply(dedup_csv).astype('string')
articles['categoryId'] = articles['categoryId'].apply(dedup_csv).astype('string')

pairs, mismatched = [], 0
for cat, cid in articles[['category','categoryId']].dropna().itertuples(index=False):
    ct, it = toks(cat), toks(cid)
    n = min(len(ct), len(it))
    if n == 0: continue
    if len(ct) != len(it): mismatched += 1
    pairs.extend(zip(ct[:n], it[:n]))

if not pairs:
    print("No category↔id pairs available.")
else:
    dfp = pd.DataFrame(pairs, columns=['cat_tok','id_tok'])
    token2id = (dfp.groupby(['cat_tok','id_tok']).size()
                  .reset_index(name='n')
                  .sort_values(['cat_tok','n','id_tok'], ascending=[True,False,True])
                  .drop_duplicates('cat_tok')
                  .set_index('cat_tok')['id_tok'])

    def rebuild_ids(cat):
        ct = toks(cat)
        mapped = [token2id.get(t, pd.NA) for t in ct if t in token2id]
        return ','.join(mapped) if mapped else pd.NA

    articles['categoryId'] = articles['category'].apply(rebuild_ids).astype('string')

# Replace missing category values with 'unknown' in place
articles['category'] = articles['category'].fillna('unknown').astype('string')

# Stats
pairs2 = []
for cat, cid in articles[['category','categoryId']].dropna().itertuples(index=False):
    ct, it = toks(cat), toks(cid)
    n = min(len(ct), len(it))
    pairs2.extend(zip(ct[:n], it[:n]))
d2 = pd.DataFrame(pairs2, columns=['cat_tok','id_tok'])

cat_stats = d2.groupby('cat_tok')['id_tok'].agg(lambda s: sorted(pd.unique(s.dropna()))).reset_index(name='unique_ids')
cat_stats['count'] = d2.groupby('cat_tok')['id_tok'].size().values

print(f"Mismatched token/id lengths: {mismatched}")
print(f"\n{'category token':40} {'unique_ids':25} count")
for _, r in cat_stats.sort_values('count', ascending=False).iterrows():
    print(f"{r['cat_tok'][:40]:40} {str(r['unique_ids'])[:25]:25} {int(r['count'])}")

multi = cat_stats['unique_ids'].apply(len) > 1
if multi.any():
    print("\nTokens mapping to >1 id:")
    for _, r in cat_stats[multi].iterrows():
        print(f"  {r['cat_tok']}: {r['unique_ids']}")
else:
    print("\n✓ Every category token maps to a single id.")

id_stats = d2.groupby('id_tok')['cat_tok'].agg(lambda s: sorted(pd.unique(s.dropna()))).reset_index(name='tokens')
multi_id = id_stats['tokens'].apply(len) > 1
if multi_id.any():
    print("\nIds used by multiple tokens:")
    for _, r in id_stats[multi_id].iterrows():
        print(f"  {r['id_tok']}: {r['tokens'][:10]}{' ...' if len(r['tokens'])>10 else ''}")
else:
    print("\n✓ No id is shared by multiple tokens.")

print(f"\nUnique categoryIds: {articles['categoryId'].str.split(',').explode().nunique(dropna=True)}")
print(f"Unique category tokens: {d2['cat_tok'].nunique(dropna=True)}")
# Out:
# Mismatched token/id lengths: 0
#
# category token                           unique_ids                count
# Bh                                       ['27']                    60899
# Underkläder                              ['19']                    52140
# Bh utan bygel                            ['50']                    41402
# Bygel-bh                                 ['223']                   20505
# REA                                      ['110']                   19798
# Sport-bh                                 ['618']                   8356
# Badkläder                                ['470']                   4607
# Framknäppt bh                            ['189']                   3813
# Överdelar                                ['1552']                  3812
# Tunikor                                  ['451']                   3805
# Dam                                      ['471']                   3439
# Byxor                                    ['689']                   3047
# Trosor                                   ['20']                    3033
# Toppar                                   ['48']                    2810
# Body                                     ['450']                   2751
# Bikini                                   ['736']                   2599
# Protes-bh                                ['122']                   2378
# Nederdelar                               ['1472']                  2106
# Baddräkter                               ['469']                   1774
# Korsetter                                ['934']                   1529
# Klänningar                               ['53']                    1225
# Minimizer                                ['808']                   1224
# Kjolar                                   ['1471']                  1143
# T-shirt-bh                               ['1997']                  1075
# Skor                                     ['1426']                  1067
# Sovkläder                                ['1451']                  1025
# Fritidskläder                            ['1667']                  739
# Blusar                                   ['1533']                  736
# Tröjor                                   ['17']                    722
# Linnen                                   ['154']                   716
# Skjortor                                 ['1519']                  690
# Mysplagg                                 ['1649']                  617
# Nattlinnen                               ['1450']                  606
# Ytterplagg                               ['2229']                  580
# Gördlar                                  ['1797']                  534
# Träningskläder                           ['1556']                  466
# Jackor                                   ['2228']                  447
# Bh-toppar                                ['40']                    425
# Västar                                   ['37']                    422
# Mjukisbyxor                              ['2110']                  405
# Koftor                                   ['14']                    389
# Strumpor                                 ['95']                    378
# Hobbyhörnan                              ['172']                   351
# Fotvård                                  ['1981']                  338
# Herr                                     ['162']                   335
# Pussel                                   ['365']                   326
# Frottéhanddukar & badlakan               ['262']                   311
# Bad                                      ['646']                   304
# Skor & tofflor                           ['1449']                  302
# Stödstrumpor                             ['639']                   294
# Bh utan kupstorlek                       ['41']                    291
# Inkontinens                              ['1145']                  246
# Shorts                                   ['1801']                  232
# Morgonrockar                             ['2363']                  231
# Fleecejackor                             ['2231']                  216
# Fritidsjackor                            ['2233']                  213
# Vardagshjälpmedel                        ['497']                   209
# T-shirts                                 ['1663']                  208
# Fritidsbyxor                             ['2117']                  206
# Tofflor                                  ['667']                   203
# Bädd (linea)                             ['612']                   192
# Bädd                                     ['371']                   191
# Lakan & örngott                          ['190']                   186
# Pussel 1000 bitar                        ['485']                   183
# Capribyxor                               ['2094']                  182
# Dukar                                    ['144']                   174
# Skotillbehör                             ['2393']                  171
# Accessoarer                              ['454']                   168
# Jeans                                    ['2112']                  163
# Balconett-bh                             ['2322']                  159
# Sjalar & halsdukar                       ['854']                   158
# Påslakanset                              ['165']                   152
# Träningsbyxor                            ['2120']                  151
# Mamelucker                               ['2325']                  135
# Underkjolar                              ['1275']                  132
# Vaxdukar                                 ['852']                   119
# Pyjamas                                  ['2132']                  118
# Badrumsmattor                            ['398']                   108
# Kanallängder                             ['175']                   108
# Tavlor                                   ['102']                   105
# Fritidsset                               ['2368']                  103
# Fritidströjor                            ['1668']                  97
# Kappor                                   ['2232']                  93
# Badrum/WC                                ['481']                   90
# Kalsonger                                ['92']                    88
# Löpare                                   ['145']                   87
# Stödartiklar                             ['1460']                  85
# Träningströjor                           ['1669']                  81
# Kroppsvård                               ['1079']                  80
# Värmeprodukter                           ['2369']                  78
# Väskor                                   ['200']                   78
# Badshorts                                ['2371']                  76
# Symaskiner och tillbehör                 ['228']                   71
# Plädar                                   ['265']                   70
# Lust                                     ['2396']                  69
# Sytillbehör                              ['151']                   68
# Belysning                                ['460']                   68
# Underklänningar                          ['1272']                  68
# Bäddtillbehör                            ['827']                   65
# Kökshanddukar                            ['276']                   65
# Halkskydd                                ['545']                   65
# Hushåll övrigt                           ['392']                   65
# Juldekoration                            ['213']                   64
# Pussel 500 bitar                         ['499']                   64
# Tankini                                  ['1835']                  64
# Kjolbaddräkter                           ['2354']                  63
# Leggings                                 ['2128']                  62
# Massage                                  ['1369']                  62
# Strumpbyxor                              ['1269']                  56
# Rollatorer                               ['2069']                  56
# Hattar                                   ['1420']                  55
# Kökshjälpmedel                           ['1418']                  55
# Kepsar & mössor                          ['1447']                  54
# Kanalkappa                               ['342']                   54
# Synhjälpmedel                            ['217']                   54
# Hälsa                                    ['1370']                  51
# Prydnadssaker                            ['208']                   51
# Handskar & vantar                        ['1415']                  48
# Morgonrockar & tofflor                   ['681']                   46
# Träning & motion                         ['1455']                  46
# Undertröjor                              ['2298']                  44
# Långkalsonger                            ['44']                    44
# Pikéer                                   ['1661']                  42
# Halsdukar & sjalar                       ['7']                     40
# Handvård                                 ['1639']                  38
# Kuddfodral                               ['248']                   38
# Servetter                                ['542']                   35
# Dekorationer                             ['166']                   35
# Trosor & gördlar                         ['2364']                  34
# Träningsset                              ['2367']                  33
# Innerkuddar                              ['517']                   32
# Gånghjälpmedel                           ['2395']                  32
# Halksockor                               ['1526']                  31
# Duschdraperier                           ['338']                   30
# Sandaler                                 ['2392']                  29
# Medicin                                  ['819']                   29
# Hushåll                                  ['284']                   28
# Kuddar                                   ['186']                   28
# Multibandslängder                        ['353']                   27
# Badrumstillbehör                         ['339']                   25
# Träningstoppar                           ['1659']                  25
# Täcken                                   ['826']                   23
# Smycken                                  ['1470']                  23
# Barnrummet                               ['195']                   23
# Gardinkappor                             ['118']                   22
# Träningsjackor                           ['1682']                  21
# Kavajer                                  ['2230']                  20
# Gardinstänger                            ['282']                   20
# Batteridrivna ljus                       ['461']                   20
# Intimvård                                ['2400']                  19
# Tvätt & skötsel                          ['926']                   19
# Konstväxter                              ['547']                   19
# Fritidsplagg                             ['3687']                  19
# Strandklänning                           ['2010']                  18
# Multibandskappa                          ['384']                   17
# Badskor                                  ['2412']                  17
# Metervara                                ['247']                   17
# Nattskjortor                             ['2381']                  16
# Strumpstickor                            ['591']                   16
# Picknick och uteliv                      ['417']                   16
# Tabletter/underlägg/brickor              ['391']                   15
# Broderikit                               ['3953']                  15
# Ljusstakar & lyktor                      ['285']                   14
# Hudvård                                  ['1638']                  14
# Överkast                                 ['244']                   14
# Hyllor & förvaring                       ['235']                   14
# Virknålar                                ['534']                   13
# Sockor & strumpor                        ['16']                    13
# Bh-tillbehör                             ['691']                   13
# Gardinbåge                               ['1031']                  13
# Sällskapsspel                            ['436']                   12
# Dynor & säten                            ['2411']                  11
# Pussel 1500 bitar                        ['546']                   11
# Sarong                                   ['2362']                  11
# Scootrar                                 ['2397']                  10
# Väskor & fodral                          ['199']                   10
# Böcker & häften                          ['128']                   9
# Pussel 350 bitar                         ['800']                   9
# Bomulls- & trasmattor                    ['275']                   8
# Handdukar                                ['224']                   8
# Underställ                               ['2377']                  8
# Ansiktsvård                              ['2408']                  7
# Påskdekoration                           ['319']                   7
# Munvård                                  ['2404']                  7
# Pussel 2000 bitar                        ['1351']                  7
# Paradhanddukar & hyllor                  ['274']                   7
# Bordslampor                              ['291']                   7
# Hällängder                               ['848']                   6
# Pussel 200 bitar                         ['2462']                  6
# Natt & garderobslampor                   ['887']                   6
# Bad- & strandkläder                      ['306']                   6
# Mörkläggningsgardiner                    ['538']                   6
# Mönster                                  ['3961']                  6
# Doftpåsar                                ['355']                   6
# Dekorationsbelysning                     ['672']                   5
# Julbelysning                             ['616']                   5
# Dörr- & trappstegsmattor                 ['433']                   5
# Öljettkappa                              ['893']                   5
# Saxar                                    ['609']                   5
# Pussel 100 bitar                         ['2461']                  5
# Sovplagg                                 ['3743']                  5
# Krukor                                   ['539']                   4
# Öljettlängder                            ['841']                   4
# Doftolja                                 ['1002']                  4
# Fönsterlampor                            ['215']                   3
# Roll up-gardiner                         ['520']                   3
# Glas & porslin                           ['486']                   3
# Pussel 32 bitar                          ['1961']                  3
# Gardinset                                ['951']                   3
# Panellängder                             ['350']                   3
# Speglar                                  ['859']                   3
# Pussel 275 bitar                         ['804']                   3
# Vepor & bonader                          ['161']                   3
# Prydnader med plats för broderi          ['330']                   3
# Batterier                                ['863']                   3
# Vaser                                    ['457']                   2
# Broderitillbehör                         ['474']                   2
# Vantar                                   ['45']                    2
# Kort                                     ['156']                   2
# Stolsdynor                               ['229']                   2
# Julgranar/kransar/girlanger              ['715']                   2
# Accessoarer granar                       ['673']                   2
# Påslakanset barn                         ['194']                   2
# Pysselset                                ['241']                   2
# Pussel 300 bitar                         ['2440']                  2
# Pussel 20 Bitar                          ['1282']                  2
# Diamond painting                         ['173']                   1
# Pussel 13 200 Bitar                      ['1284']                  1
# Julstrumpor                              ['349']                   1
# Julkalendrar                             ['72']                    1
# Hårvård                                  ['2409']                  1
# Mössor & hattar                          ['39']                    1
# Paint by numbers                         ['233']                   1
# Heminredning                             ['10']                    1
# Pussel 24 bitar                          ['3813']                  1
# Vägglampor                               ['280']                   1
# Broderier utan garn                      ['459']                   1
# Pussel 3000 Bitar                        ['1281']                  1
# Pussel 4000 bitar                        ['2455']                  1
# Gardintillbehör                          ['644']                   1
# Spetsar & band                           ['703']                   1
# Sticktillbehör                           ['33']                    1
# Gardiner (linea)                         ['3754']                  1
# Flexitavlor                              ['155']                   1
# Övriga broderier                         ['230']                   1
#
# ✓ Every category token maps to a single id.
#
# ✓ No id is shared by multiple tokens.
#
# Unique categoryIds: 245
# Unique category tokens: 245

# %% [markdown]
# ## Brand

# %%
# --- Brand cleanup + backfill (concise, no warnings) ---

# Normalize
def _norm_brand(s):
    if pd.isna(s): return pd.NA
    s = ' '.join(str(s).strip().split())  # collapse whitespace
    return s or pd.NA

articles['brand']  = articles['brand'].astype('string').apply(_norm_brand)
articles['brandId'] = articles['brandId'].astype('string').str.strip()

# Build maps from known (non-missing) pairs
known = articles.dropna(subset=['brand', 'brandId'])[['brand','brandId']].drop_duplicates()
name_to_id = (known.groupby('brand')['brandId']
              .agg(lambda s: s.mode().iat[0] if len(s.mode()) else s.iloc[0]))

id_to_name = (known.groupby('brandId')['brand']
              .agg(lambda s: s.mode().iat[0] if len(s.mode()) else s.iloc[0]))

# Backfill missing brandId from brand
mask = articles['brandId'].isna() & articles['brand'].notna()
filled_ids = articles.loc[mask, 'brand'].map(name_to_id).astype('string')
# align and assign (avoids FutureWarning)
filled_ids = filled_ids.reindex(articles.index)
articles.loc[mask, 'brandId'] = filled_ids

# Now fill missing brand text with 'unknown' (do this AFTER normalization/backfill)
articles['brand'] = articles['brand'].fillna('unknown').astype('string')

# %% [markdown]
# # Price

# %%
articles['priceSEK'].isna().sum()
# Out:
# 152

# %%
import pandas as pd
import requests

# --- Rates (SEK per unit) ----------------------------------------------------
def sek_rates(timeout=8):
    fallback = {"EUR": 11.5, "NOK": 1.0, "DKK": 1.55, "asof": "fallback"}
    try:
        r = requests.get("https://api.frankfurter.app/latest",
                         params={"base": "EUR", "symbols": "SEK,NOK,DKK"},
                         timeout=timeout)
        r.raise_for_status()
        data = r.json()
        eur_sek = float(data["rates"]["SEK"])
        nok_sek = eur_sek / float(data["rates"]["NOK"])
        dkk_sek = eur_sek / float(data["rates"]["DKK"])
        return {"EUR": eur_sek, "NOK": nok_sek, "DKK": dkk_sek, "asof": data.get("date", "unknown")}
    except Exception:
        return fallback

rates = sek_rates()
EUR_to_SEK, NOK_to_SEK, DKK_to_SEK = rates["EUR"], rates["NOK"], rates["DKK"]
print(f"Using rates (SEK per unit) as of {rates['asof']}: EUR={EUR_to_SEK:.6f}, NOK={NOK_to_SEK:.6f}, DKK={DKK_to_SEK:.6f}")

# --- Fill priceSEK (vectorized) ----------------------------------------------
articles = articles.copy()

# Ensure needed cols exist
for c in ["priceSEK", "priceEUR", "priceNOK", "priceDKK"]:
    if c not in articles.columns:
        articles[c] = pd.NA

def _num(s):
    # normalize spaces + decimal comma, then coerce to float
    s = (s.astype("string")
           .str.replace(r"[ \u00A0]", "", regex=True)
           .str.replace(",", ".", regex=False))
    return pd.to_numeric(s, errors="coerce")

eur = _num(articles["priceEUR"])
nok = _num(articles["priceNOK"])
dkk = _num(articles["priceDKK"])

eur_sek = eur * EUR_to_SEK
nok_sek = nok * NOK_to_SEK
dkk_sek = dkk * DKK_to_SEK

# first available: EUR→SEK, else NOK→SEK, else DKK→SEK
calc_sek = eur_sek.fillna(nok_sek).fillna(dkk_sek)

mask = articles["priceSEK"].isna()
num_to_replace = int(mask.sum())

# round down to no decimals, cast to string; fill only missing priceSEK
filled = calc_sek.round(0).astype("Int64").astype("string")
articles.loc[mask, "priceSEK"] = filled.loc[mask]

# uniform dtype
articles["priceSEK"] = articles["priceSEK"].astype("string")

num_replaced = int(articles.loc[mask, "priceSEK"].notna().sum())
print(f"Filled priceSEK for {num_replaced} rows (out of {num_to_replace} missing).")
# Out:
# Using rates (SEK per unit) as of 2025-10-03: EUR=11.003000, NOK=0.942481, DKK=1.473609
# Filled priceSEK for 152 rows (out of 152 missing).

# %%
# Set priceSEK for specific SKUs as requested
articles.loc[articles['sku'] == '270607-5254', 'priceSEK'] = '1310'
articles.loc[articles['sku'] == '270534-03xl', 'priceSEK'] = '419'

# %%
# Output rows where priceSEK is more than 10000 (as SEK)
# First, create a mask for priceSEK > 10000 (as float), then use it to index articles
priceSEK_numeric = pd.to_numeric(articles['priceSEK'], errors='coerce')
high_price_mask = priceSEK_numeric > 10000
high_price_rows = articles[high_price_mask]
high_price_rows
# Out:
#           sku groupId brandId                            name     brand  \
# 9337   294850  294850      33                     Scooter Leo  Invacare
# 9338   294843  294843      33                     Scooter Leo  Invacare
# 9339   294835  294835      33                 Scooter Colibri  Invacare
# 9508   290036  290036      33      Scooter Orion Metro 3-hjul  Invacare
# 9521   290052  290052      33      Scooter Orion Metro 4 hjul  Invacare
# 9537   290045  290045      33      Scooter Orion Metro 3 hjul  Invacare
# 9770   294124  294124      33                   Scooter Orion  Invacare
# 9936   294447  294447       5                     Massagestol    beurer
# 11105  340569  340569     132  Sy-Broderimaskin Singer SE9185    Singer
# 93816  294884  294884    <NA>       Scooter Orion 3-hjul  ink   unknown
#
#                                    category categoryId priceSEK priceEUR  \
# 9337                               Scootrar       2397    24998     2498
# 9338                               Scootrar       2397    24998     2498
# 9339                               Scootrar       2397    19998     1998
# 9508                    Scootrar,Rollatorer  2397,2069    31989     3367
# 9521                               Scootrar       2397    34998     3498
# 9537                               Scootrar       2397    34998     3498
# 9770                    Scootrar,Rollatorer  2397,2069    25500     2650
# 9936                                Massage       1369    16519     1698
# 11105  Sytillbehör,Symaskiner och tillbehör    151,228    20998   1898.9
# 93816                   Scootrar,Rollatorer  2397,2069    28995     <NA>
#
#       priceNOK priceDKK forSale
# 9337     24998    24998    <NA>
# 9338     24998    24998    <NA>
# 9339     19998    19998    <NA>
# 9508     31989    31989    <NA>
# 9521     34998    34998    <NA>
# 9537     34998    34998    <NA>
# 9770     25500    25500    <NA>
# 9936     17998    16519    <NA>
# 11105    21998    13998       1
# 93816    28995     <NA>    <NA>

# %%
# Save the cleaned articles DataFrame to a parquet file in the 'processed' directory
articles.to_parquet("../data/processed/articles_clean.parquet", index=False)
